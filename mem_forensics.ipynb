# %%
import os
import sys
import glob
from itertools import izip
import pandas as pd
path='/home/gaurav/malware_combine_result/Results_Malware/result_'
final_dict='/home/gaurav/malware_combine_result/Results_clean/final_dict'

feature=[]


dic_final=open(final_dict,"a")
for i in range(0,27):
    
    fp=path+str(i)
    #print i
    #print '#########################################################'
    
    with open(os.path.join(fp,'dict1'),'r')as a,open(os.path.join(fp,'dll1'),'r')as b,open(os.path.join(fp,'envars'),'r')as c,open(os.path.join(fp,'file_names'),'r')as d,open(os.path.join(fp,'mutex'),'r')as e:
              #print 'hello'
              
              count=0  
              for p,q,r,s,t in izip(a,b,c,d,e):
                    dict_1={}
                    p = eval(p.strip())
                    q = eval(q.strip())
                    r = eval(r.strip())
                    s = eval(s.strip())
                    t = eval(t.strip())
                    
                    dict_1=dict(dict_1.items()+p.items())
                    dict_1=dict(dict_1.items()+q.items())
                    dict_1=dict(dict_1.items()+r.items())
                    dict_1=dict(dict_1.items()+s.items())
                    dict_1=dict(dict_1.items()+t.items())
                    
                    
                   
                  
                    feature.append(dict_1)

                    count+=1
                    #print count
                    
                    
                    
                  
                    
    
    


  #     fp= str(fp)
#     f= open(fp,"r")
    #print f
    #with open(fp,'r') as file:
       #print file
    #feature=[]
    #c=1
    #for line in file:
        #feature.append(eval(line))
        #print c
        #print line
        #c+=1
        
#print feature[1]
#print feature[0]

# %%
print len(feature)
# Out:
# 1766

# %%
df0=pd.DataFrame.from_records(feature).fillna(0)
list1=[]
df0['possible_code_injection']= df0['possible_code_injection']/(df0['no._of_child']+1)#@@@@@@@@@@@@@@@@@@@

for names in df0:
     if df0[names].std() > 0.2:
            print names
            list1.append(names)
            print df0[names].sum()
# Out:
# 570.0
#
# Collects information about system
# 13071
#
# Has access to autorun registry keys
# 9277
#
# Identifies installed programs
# 15
#
# Queries / modifies encryption seettings
# 238
#
# Queries / modifies network settings
# 47
#
# Queries / modifies proxy settings
# 1830
#
# Reads information about supported languages
# 1206
# !IETld!Mutex
# 268.0
# Can access the clipboard
# 93
# Can bypass UAC
# 154
# Can create or write to files
# 629
# Can enumerate free disk space
# 139
# Can enumerate system information
# 826
# Can enumerate username
# 94
# Can identify machine time
# 299
# Can identify machine version information
# 332
# Can inject code to other processes
# 1002
# Can interact with the registry
# 512
# Can query startup information
# 209
# Can receive or send files from or to internet
# 1571
# Can track keyboard strokes
# 114
# Can use antidebug techniques
# 1723
# FWPUCLNT.DLL
# 270.0
# GoogleUpdate.e
# 124.0
# IPHLPAPI.DLL
# 406.0
# IPcount netscan
# 7042
# KernelBase.dll
# 654.0
# KernelBase.dll.mui
# 254.0
# Keylogger traces (messagehooks)
# 1338
# Mutants_accessed
# 5069
# NapiNSP.dll
# 266.0
# RasPbFile
# 299.0
# RpcRtRemote.dll
# 127.0
# SearchFilterHo
# 808.0
# SensApi.dll
# 215.0
# StaticCache.dat
# 402.0
# Susp DLLs (atoms)
# 294
# Susp DLLs (atomscan)
# 294
# Susp DLLs/EXEs (dlllist)
# 37438
# Temporary
# 338.0
# Unusual process PID
# 15
# Unusual timers.
# 13013
# WSHTCPIP.DLL
# 359.0
# WininetConnectionMutex
# 331.0
# WininetProxyRegistryMutex
# 331.0
# WininetStartupMutex
# 331.0
# Wldap32.dll
# 407.0
# ZoneAttributeCacheCounterMutex
# 316.0
# ZonesCacheCounterMutex
# 316.0
# ZonesCounterMutex
# 316.0
# ZonesLockedCacheCounterMutex
# 316.0
# _!MSFTHISTORY!_
# 338.0
# advapi32.dll
# 653.0
# apphelp.dll
# 329.0
# bcrypt.dll
# 120.0
# bcryptprimitives.dll
# 109.0
# c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!
# 338.0
# c:!users!gaurav!appdata!local!microsoft!windows!temporary
# 338.0
# c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!
# 338.0
# cabinet.dll
# 108.0
# cfgmgr32.dll
# 362.0
# clbcatq.dll
# 460.0
# comctl32.dll
# 526.0
# comctl32.dll.mui
# 91.0
# comdlg32.dll
# 168.0
# count_run_temp_dir
# 1229
# credssp.dll
# 144.0
# crypt32.dll
# 415.0
# cryptbase.dll
# 652.0
# cryptnet.dll
# 107.0
# cryptsp.dll
# 261.0
# devobj.dll
# 324.0
# devrtl.dll
# 98.0
# dhcpcsvc.dll
# 141.0
# dhcpcsvc6.dll
# 133.0
# dll_for_proc
# 36008
# dnsapi.dll
# 397.0
# dwmapi.dll
# 349.0
# explorer.exe
# 397.0
# gdi32.dll
# 651.0
# gpapi.dll
# 109.0
# hidden/Susp DLLs/EXEs(ldermodules)
# 90792
# ieframe.dll
# 175.0
# iertutil.dll
# 405.0
# imageres.dll
# 137.0
# imm32.dll
# 651.0
# index.dat
# 338.0
# index143.dat
# 82.0
# install.exe
# 89.0
# interesting files accessed
# 2762
# kernel32.dll
# 652.0
# lpk.dll
# 651.0
# mlang.dll
# 93.0
# mpr.dll
# 122.0
# msasn1.dll
# 416.0
# mscorrc.dll
# 133.0
# mscorsvw.exe
# 242.0
# msctf.dll
# 651.0
# msimg32.dll
# 103.0
# msvcrt.dll
# 652.0
# mswsock.dll
# 399.0
# ncrypt.dll
# 109.0
# netapi32.dll
# 86.0
# netutils.dll
# 88.0
# new services
# 2148
# nlaapi.dll
# 266.0
# no. of malfinds
# 7452
# no._of_child
# 1176
# no._of_envars
# 2014
# no_proc_in_hollow
# 1807
# normaliz.dll
# 95.0
# nsExec.dll
# 80.0
# nsi.dll
# 468.0
# ntdll.dll
# 652.0
# ntmarta.dll
# 373.0
# ole32.dll
# 610.0
# oleacc.dll
# 161.0
# oleaccrc.dll
# 245.0
# oleaut32.dll
# 598.0
# pnrpnsp.dll
# 266.0
# possible_code_injection
# 11679.373481116585
# profapi.dll
# 515.0
# propsys.dll
# 288.0
# psapi.dll
# 230.0
# pubpol4.dat
# 145.0
# python.exe
# 1426.0
# rasadhlp.dll
# 328.0
# rasapi32.dll
# 208.0
# rasman.dll
# 208.0
# rpcrt4.dll
# 652.0
# rsaenh.dll
# 262.0
# rtutils.dll
# 185.0
# samcli.dll
# 110.0
# schannel.dll
# 93.0
# sechost.dll
# 652.0
# secur32.dll
# 117.0
# setupapi.dll
# 324.0
# setupapi.dll.mui
# 155.0
# shdocvw.dll
# 224.0
# shell32.dll
# 580.0
# shfolder.dll
# 147.0
# shlwapi.dll
# 618.0
# sortkey.nlp
# 145.0
# sorttbls.nlp
# 145.0
# srvcli.dll
# 114.0
# sspicli.dll
# 651.0
# suspicious_files
# 82827
# sxs.dll
# 152.0
# tcl8.5
# 661.0
# tix8.4.3
# 661.0
# tk8.5
# 661.0
# urlmon.dll
# 379.0
# urlmon.dll.mui
# 274.0
# user32.dll
# 651.0
# user32.dll.mui
# 139.0
# userenv.dll
# 218.0
# usp10.dll
# 651.0
# uxtheme.dll
# 552.0
# version.dll
# 512.0
# webio.dll
# 141.0
# winhttp.dll
# 141.0
# winhttp.dll.mui
# 122.0
# wininet.dll
# 379.0
# winmm.dll
# 143.0
# winnsi.dll
# 406.0
# winrnr.dll
# 266.0
# wintrust.dll
# 125.0
# wkscli.dll
# 86.0
# wmpnetwk.exe
# 87.0
# ws2_32.dll
# 468.0
# wship6.dll
# 260.0
# wsock32.dll
# 111.0

# %%
path='/home/gaurav/malware_combine_result/Results_clean/result_'

feature1=[]



count=0 
for i in range(0,23):
    
    fp=path+str(i)
    #print i
    #print '#########################################################'
    
    with open(os.path.join(fp,'dict1'),'r')as a,open(os.path.join(fp,'dll1'),'r')as b,open(os.path.join(fp,'envars'),'r')as c,open(os.path.join(fp,'file_names'),'r')as d,open(os.path.join(fp,'mutex'),'r')as e:
              #print 'hello'
              
              
              for p,q,r,s,t in izip(a,b,c,d,e):
                    dict_1={}
                    p = eval(p.strip())
                    q = eval(q.strip())
                    r = eval(r.strip())
                    s = eval(s.strip())
                    t = eval(t.strip())
                    
                    dict_1=dict(dict_1.items()+p.items())
                    dict_1=dict(dict_1.items()+q.items())
                    dict_1=dict(dict_1.items()+r.items())
                    dict_1=dict(dict_1.items()+s.items())
                    dict_1=dict(dict_1.items()+t.items())
                    
                    
                   
                    #print dict_1
                    feature1.append(dict_1)

                    count+=1
                    #if count>490:
                        #break
                    
                    
                    
    #if count>490:
            #break              
                    
    
    

        
print len(feature1)
#print feature1
# Out:
# 1544

# %%
df1=pd.DataFrame.from_records(feature1).fillna(0)
list2=[]
df1['possible_code_injection']= df1['possible_code_injection']/(df1['no._of_child']+1)
for names in df1:
     if df1[names].std() > 0.2:
            #print names
            list2.append(names)
            #print df1[names].sum()
            if names in df0:
                print names+' '+str(df0[names].sum())+' '+str(df1[names].sum())

print df1['possible_code_injection'].sum()
# Out:
#  570.0 485.0
#
# Collects information about system 13071 9519
#
# Has access to autorun registry keys 9277 4435
#
# Queries / modifies encryption seettings 238 174
#
# Queries / modifies network settings 47 147
#
# Queries / modifies proxy settings 1830 1325
#
# Reads information about supported languages 1206 1352
# !IETld!Mutex 268.0 79.0
# Associated service  0 49
# BootstrapperApplicationData.xml 5.0 92.0
# BootstrapperCore.dll 7.0 113.0
# Can access the clipboard  93 78
# Can bypass UAC  154 258
# Can create atoms  54 78
# Can create or start services  50 84
# Can create or write to files  629 719
# Can enumerate free disk space  139 139
# Can enumerate system information  826 847
# Can enumerate username  94 101
# Can identify machine time  299 414
# Can identify machine version information  332 393
# Can inject code to other processes  1002 1077
# Can interact with the registry  512 526
# Can query startup information  209 238
# Can receive or send files from or to internet  1571 1040
# Can restart or shutdown the system  67 79
# Can track keyboard strokes  114 140
# Can use antidebug techniques  1723 1869
# DBWinMutex 35.0 119.0
# ExplorerFrame.dll 13.0 80.0
# FWPUCLNT.DLL 270.0 136.0
# GdiPlus.dll 39.0 136.0
# IPHLPAPI.DLL 406.0 178.0
# IPcount netscan 7042 6174
# KernelBase.dll 654.0 512.0
# KernelBase.dll.mui 254.0 302.0
# Keylogger traces (messagehooks) 1338 641
# LocalizableStrings.xml 5.0 92.0
# ManagedUx.dll 7.0 110.0
# Microsoft.ApplicationInsights.PersistenceChannel.dll 3.0 66.0
# Microsoft.ApplicationInsights.dll 3.0 66.0
# Microsoft.Diagnostics.Tracing.EventSource.dll 3.0 66.0
# Microsoft.VS.PlatformInstaller.DynamicFeed.dll 3.0 66.0
# Microsoft.VisualStudio.Telemetry.Net35.dll 3.0 66.0
# Mutants_accessed 5069 3115
# Newtonsoft.Json.dll 3.0 66.0
# PresentationCore.ni.dll 2.0 87.0
# PresentationFo 4.0 94.0
# PresentationFramework.ni.dll 2.0 87.0
# Program 47.0 107.0
# RasPbFile 299.0 153.0
# RpcRtRemote.dll 127.0 202.0
# SearchFilterHo 808.0 953.0
# SensApi.dll 215.0 119.0
# StaticCache.dat 402.0 540.0
# Susp DLLs (atoms) 294 383
# Susp DLLs (atomscan) 294 383
# Susp DLLs/EXEs (dlllist) 37438 32297
# System.Configuration.ni.dll 3.0 90.0
# System.Core.ni.dll 2.0 91.0
# System.Drawing.ni.dll 22.0 68.0
# System.Threading.dll 3.0 66.0
# System.Windows.Forms.ni.dll 22.0 67.0
# System.Xml.ni.dll 3.0 92.0
# System.ni.dll 24.0 95.0
# Temporary 338.0 155.0
# Unusual timers. 13013 11312
# User 21.0 69.0
# WSHTCPIP.DLL 359.0 139.0
# WindowsBase.ni.dll 3.0 87.0
# WindowsCodecs.dll 20.0 97.0
# WindowsUpdate.log 6.0 112.0
# WindowsUpdateTracingMutex 6.0 112.0
# WininetConnectionMutex 331.0 148.0
# WininetProxyRegistryMutex 331.0 148.0
# WininetStartupMutex 331.0 148.0
# Wldap32.dll 407.0 260.0
# ZoneAttributeCacheCounterMutex 316.0 160.0
# ZonesCacheCounterMutex 316.0 160.0
# ZonesCounterMutex 316.0 160.0
# ZonesLockedCacheCounterMutex 316.0 160.0
# _!MSFTHISTORY!_ 338.0 154.0
# __DDrawCheckExclMode__ 17.0 113.0
# __DDrawExclMode__ 17.0 113.0
# advapi32.dll 653.0 495.0
# apphelp.dll 329.0 307.0
# atl.dll 69.0 127.0
# bcrypt.dll 120.0 147.0
# bcryptprimitives.dll 109.0 145.0
# c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5! 338.0 153.0
# c:!users!gaurav!appdata!local!microsoft!windows!temporary 338.0 154.0
# c:!users!gaurav!appdata!roaming!microsoft!windows!cookies! 338.0 153.0
# cabinet.dll 108.0 123.0
# cfgmgr32.dll 362.0 317.0
# chrome.exe 31.0 78.0
# clbcatq.dll 460.0 330.0
# comctl32.dll 526.0 416.0
# comctl32.dll.mui 91.0 139.0
# comdlg32.dll 168.0 183.0
# count_run_temp_dir 1229 1086
# credssp.dll 144.0 114.0
# crypt32.dll 415.0 285.0
# cryptbase.dll 652.0 497.0
# cryptnet.dll 107.0 106.0
# cryptsp.dll 261.0 234.0
# devobj.dll 324.0 261.0
# devrtl.dll 98.0 128.0
# dhcpcsvc.dll 141.0 123.0
# dhcpcsvc6.dll 133.0 115.0
# dll_for_proc 36008 32825
# dnsapi.dll 397.0 154.0
# dui70.dll 18.0 84.0
# duser.dll 21.0 88.0
# dwmapi.dll 349.0 433.0
# explorer.exe 397.0 229.0
# fastprox.dll 12.0 106.0
# gdi32.dll 651.0 493.0
# gpapi.dll 109.0 110.0
# hidden/Susp DLLs/EXEs(ldermodules) 90792 71774
# iertutil.dll 405.0 255.0
# imagehlp.dll 43.0 108.0
# imageres.dll 137.0 79.0
# imm32.dll 651.0 492.0
# index.dat 338.0 153.0
# index127.dat 24.0 99.0
# interesting files accessed 2762 4613
# kernel32.dll 652.0 512.0
# lpk.dll 651.0 492.0
# mbahost.dll 5.0 112.0
# mbapreq.dll 5.0 93.0
# mbapreq.png 5.0 92.0
# mbapreq.thm 5.0 92.0
# mbapreq.wxl 5.0 92.0
# mpr.dll 122.0 134.0
# msasn1.dll 416.0 306.0
# mscoree.dll 23.0 111.0
# mscoreei.dll 23.0 111.0
# mscorjit.dll 22.0 88.0
# mscorlib.ni.dll 24.0 102.0
# mscorrc.dll 133.0 137.0
# mscorsec.dll 11.0 85.0
# mscorsvw.exe 242.0 92.0
# mscorwks.dll 22.0 89.0
# msctf.dll 651.0 492.0
# msctfui.dll.mui 2.0 86.0
# msi.dll 32.0 157.0
# msimg32.dll 103.0 92.0
# msvcr80.dll 24.0 91.0
# msvcrt.dll 652.0 512.0
# mswsock.dll 399.0 152.0
# msxml3.dll 15.0 123.0
# msxml3r.dll 32.0 156.0
# ncrypt.dll 109.0 138.0
# netmsg.dll 20.0 72.0
# netutils.dll 88.0 145.0
# new services 2148 1326
# no. of malfinds 7452 5807
# no._of_child 1176 1432
# no._of_envars 2014 2189
# no_proc_in_hollow 1807 1502
# normaliz.dll 95.0 72.0
# nsi.dll 468.0 256.0
# ntdll.dll 652.0 513.0
# ntdsapi.dll 14.0 108.0
# ntmarta.dll 373.0 243.0
# ole32.dll 610.0 479.0
# oleacc.dll 161.0 71.0
# oleaccrc.dll 245.0 142.0
# oleaut32.dll 598.0 460.0
# possible_code_injection 11679.373481116585 9315.037130725399
# profapi.dll 515.0 331.0
# propsys.dll 288.0 208.0
# psapi.dll 230.0 87.0
# pubpol4.dat 145.0 148.0
# python.exe 1426.0 1122.0
# rasadhlp.dll 328.0 137.0
# rasapi32.dll 208.0 83.0
# rasman.dll 208.0 82.0
# riched20.dll 44.0 111.0
# rpcrt4.dll 652.0 497.0
# rsaenh.dll 262.0 233.0
# rtutils.dll 185.0 81.0
# samcli.dll 110.0 99.0
# schannel.dll 93.0 65.0
# sechost.dll 652.0 497.0
# secur32.dll 117.0 130.0
# setupapi.dll 324.0 262.0
# setupapi.dll.mui 155.0 103.0
# shell32.dll 580.0 449.0
# shfolder.dll 147.0 169.0
# shlwapi.dll 618.0 464.0
# sortkey.nlp 145.0 126.0
# sorttbls.nlp 145.0 126.0
# sqmapi.dll 5.0 93.0
# srvcli.dll 114.0 102.0
# sspicli.dll 651.0 497.0
# suspicious_files 82827 74565
# tcl8.5 661.0 694.0
# tix8.4.3 661.0 694.0
# tk8.5 661.0 694.0
# urlmon.dll 379.0 252.0
# urlmon.dll.mui 274.0 82.0
# user32.dll 651.0 493.0
# user32.dll.mui 139.0 111.0
# userenv.dll 218.0 219.0
# usp10.dll 651.0 492.0
# uxtheme.dll 552.0 449.0
# version.dll 512.0 370.0
# wbemcomn.dll 12.0 106.0
# wbemprox.dll 12.0 106.0
# wbemsvc.dll 12.0 106.0
# webio.dll 141.0 124.0
# winhttp.dll 141.0 124.0
# winhttp.dll.mui 122.0 135.0
# wininet.dll 379.0 252.0
# winmm.dll 143.0 192.0
# winnsi.dll 406.0 178.0
# winspool.drv 66.0 120.0
# wintrust.dll 125.0 156.0
# wkscli.dll 86.0 145.0
# wmiutils.dll 3.0 86.0
# wpfgfx_v0300.dll 2.0 85.0
# ws2_32.dll 468.0 246.0
# wship6.dll 260.0 134.0
# wtsapi32.dll 19.0 66.0
# 9315.037130725399

# %%
list3=[]
for names in df0:
     if df0[names].std() > 0.2:
            #print names
            
            #print df1[names].sum()
            if names in df1:
                print names+' '+str(df0[names].sum())+' '+str(df1[names].sum())
# Out:
#  570.0 485.0
#
# Collects information about system 13071 9519
#
# Has access to autorun registry keys 9277 4435
#
# Identifies installed programs 15 7
#
# Queries / modifies encryption seettings 238 174
#
# Queries / modifies network settings 47 147
#
# Queries / modifies proxy settings 1830 1325
#
# Reads information about supported languages 1206 1352
# !IETld!Mutex 268.0 79.0
# Can access the clipboard  93 78
# Can bypass UAC  154 258
# Can create or write to files  629 719
# Can enumerate free disk space  139 139
# Can enumerate system information  826 847
# Can enumerate username  94 101
# Can identify machine time  299 414
# Can identify machine version information  332 393
# Can inject code to other processes  1002 1077
# Can interact with the registry  512 526
# Can query startup information  209 238
# Can receive or send files from or to internet  1571 1040
# Can track keyboard strokes  114 140
# Can use antidebug techniques  1723 1869
# FWPUCLNT.DLL 270.0 136.0
# GoogleUpdate.e 124.0 44.0
# IPHLPAPI.DLL 406.0 178.0
# IPcount netscan 7042 6174
# KernelBase.dll 654.0 512.0
# KernelBase.dll.mui 254.0 302.0
# Keylogger traces (messagehooks) 1338 641
# Mutants_accessed 5069 3115
# NapiNSP.dll 266.0 56.0
# RasPbFile 299.0 153.0
# RpcRtRemote.dll 127.0 202.0
# SearchFilterHo 808.0 953.0
# SensApi.dll 215.0 119.0
# StaticCache.dat 402.0 540.0
# Susp DLLs (atoms) 294 383
# Susp DLLs (atomscan) 294 383
# Susp DLLs/EXEs (dlllist) 37438 32297
# Temporary 338.0 155.0
# Unusual process PID 15 0
# Unusual timers. 13013 11312
# WSHTCPIP.DLL 359.0 139.0
# WininetConnectionMutex 331.0 148.0
# WininetProxyRegistryMutex 331.0 148.0
# WininetStartupMutex 331.0 148.0
# Wldap32.dll 407.0 260.0
# ZoneAttributeCacheCounterMutex 316.0 160.0
# ZonesCacheCounterMutex 316.0 160.0
# ZonesCounterMutex 316.0 160.0
# ZonesLockedCacheCounterMutex 316.0 160.0
# _!MSFTHISTORY!_ 338.0 154.0
# advapi32.dll 653.0 495.0
# apphelp.dll 329.0 307.0
# bcrypt.dll 120.0 147.0
# bcryptprimitives.dll 109.0 145.0
# c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5! 338.0 153.0
# c:!users!gaurav!appdata!local!microsoft!windows!temporary 338.0 154.0
# c:!users!gaurav!appdata!roaming!microsoft!windows!cookies! 338.0 153.0
# cabinet.dll 108.0 123.0
# cfgmgr32.dll 362.0 317.0
# clbcatq.dll 460.0 330.0
# comctl32.dll 526.0 416.0
# comctl32.dll.mui 91.0 139.0
# comdlg32.dll 168.0 183.0
# count_run_temp_dir 1229 1086
# credssp.dll 144.0 114.0
# crypt32.dll 415.0 285.0
# cryptbase.dll 652.0 497.0
# cryptnet.dll 107.0 106.0
# cryptsp.dll 261.0 234.0
# devobj.dll 324.0 261.0
# devrtl.dll 98.0 128.0
# dhcpcsvc.dll 141.0 123.0
# dhcpcsvc6.dll 133.0 115.0
# dll_for_proc 36008 32825
# dnsapi.dll 397.0 154.0
# dwmapi.dll 349.0 433.0
# explorer.exe 397.0 229.0
# gdi32.dll 651.0 493.0
# gpapi.dll 109.0 110.0
# hidden/Susp DLLs/EXEs(ldermodules) 90792 71774
# ieframe.dll 175.0 36.0
# iertutil.dll 405.0 255.0
# imageres.dll 137.0 79.0
# imm32.dll 651.0 492.0
# index.dat 338.0 153.0
# index143.dat 82.0 9.0
# install.exe 89.0 10.0
# interesting files accessed 2762 4613
# kernel32.dll 652.0 512.0
# lpk.dll 651.0 492.0
# mlang.dll 93.0 16.0
# mpr.dll 122.0 134.0
# msasn1.dll 416.0 306.0
# mscorrc.dll 133.0 137.0
# mscorsvw.exe 242.0 92.0
# msctf.dll 651.0 492.0
# msimg32.dll 103.0 92.0
# msvcrt.dll 652.0 512.0
# mswsock.dll 399.0 152.0
# ncrypt.dll 109.0 138.0
# netapi32.dll 86.0 64.0
# netutils.dll 88.0 145.0
# new services 2148 1326
# nlaapi.dll 266.0 58.0
# no. of malfinds 7452 5807
# no._of_child 1176 1432
# no._of_envars 2014 2189
# no_proc_in_hollow 1807 1502
# normaliz.dll 95.0 72.0
# nsExec.dll 80.0 1.0
# nsi.dll 468.0 256.0
# ntdll.dll 652.0 513.0
# ntmarta.dll 373.0 243.0
# ole32.dll 610.0 479.0
# oleacc.dll 161.0 71.0
# oleaccrc.dll 245.0 142.0
# oleaut32.dll 598.0 460.0
# pnrpnsp.dll 266.0 56.0
# possible_code_injection 11679.373481116585 9315.037130725399
# profapi.dll 515.0 331.0
# propsys.dll 288.0 208.0
# psapi.dll 230.0 87.0
# pubpol4.dat 145.0 148.0
# python.exe 1426.0 1122.0
# rasadhlp.dll 328.0 137.0
# rasapi32.dll 208.0 83.0
# rasman.dll 208.0 82.0
# rpcrt4.dll 652.0 497.0
# rsaenh.dll 262.0 233.0
# rtutils.dll 185.0 81.0
# samcli.dll 110.0 99.0
# schannel.dll 93.0 65.0
# sechost.dll 652.0 497.0
# secur32.dll 117.0 130.0
# setupapi.dll 324.0 262.0
# setupapi.dll.mui 155.0 103.0
# shdocvw.dll 224.0 56.0
# shell32.dll 580.0 449.0
# shfolder.dll 147.0 169.0
# shlwapi.dll 618.0 464.0
# sortkey.nlp 145.0 126.0
# sorttbls.nlp 145.0 126.0
# srvcli.dll 114.0 102.0
# sspicli.dll 651.0 497.0
# suspicious_files 82827 74565
# sxs.dll 152.0 31.0
# tcl8.5 661.0 694.0
# tix8.4.3 661.0 694.0
# tk8.5 661.0 694.0
# urlmon.dll 379.0 252.0
# urlmon.dll.mui 274.0 82.0
# user32.dll 651.0 493.0
# user32.dll.mui 139.0 111.0
# userenv.dll 218.0 219.0
# usp10.dll 651.0 492.0
# uxtheme.dll 552.0 449.0
# version.dll 512.0 370.0
# webio.dll 141.0 124.0
# winhttp.dll 141.0 124.0
# winhttp.dll.mui 122.0 135.0
# wininet.dll 379.0 252.0
# winmm.dll 143.0 192.0
# winnsi.dll 406.0 178.0
# winrnr.dll 266.0 56.0
# wintrust.dll 125.0 156.0
# wkscli.dll 86.0 145.0
# wmpnetwk.exe 87.0 19.0
# ws2_32.dll 468.0 246.0
# wship6.dll 260.0 134.0
# wsock32.dll 111.0 43.0

# %%
list3=list1+list2
print list3
# Out:
# ['', '\nCollects information about system', '\nHas access to autorun registry keys', '\nIdentifies installed programs', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Can access the clipboard ', 'Can bypass UAC ', 'Can create or write to files ', 'Can enumerate free disk space ', 'Can enumerate system information ', 'Can enumerate username ', 'Can identify machine time ', 'Can identify machine version information ', 'Can inject code to other processes ', 'Can interact with the registry ', 'Can query startup information ', 'Can receive or send files from or to internet ', 'Can track keyboard strokes ', 'Can use antidebug techniques ', 'FWPUCLNT.DLL', 'GoogleUpdate.e', 'IPHLPAPI.DLL', 'IPcount netscan', 'KernelBase.dll', 'KernelBase.dll.mui', 'Keylogger traces (messagehooks)', 'Mutants_accessed', 'NapiNSP.dll', 'RasPbFile', 'RpcRtRemote.dll', 'SearchFilterHo', 'SensApi.dll', 'StaticCache.dat', 'Susp DLLs (atoms)', 'Susp DLLs (atomscan)', 'Susp DLLs/EXEs (dlllist)', 'Temporary', 'Unusual process PID', 'Unusual timers.', 'WSHTCPIP.DLL', 'WininetConnectionMutex', 'WininetProxyRegistryMutex', 'WininetStartupMutex', 'Wldap32.dll', 'ZoneAttributeCacheCounterMutex', 'ZonesCacheCounterMutex', 'ZonesCounterMutex', 'ZonesLockedCacheCounterMutex', '_!MSFTHISTORY!_', 'advapi32.dll', 'apphelp.dll', 'bcrypt.dll', 'bcryptprimitives.dll', 'c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!', 'c:!users!gaurav!appdata!local!microsoft!windows!temporary', 'c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!', 'cabinet.dll', 'cfgmgr32.dll', 'clbcatq.dll', 'comctl32.dll', 'comctl32.dll.mui', 'comdlg32.dll', 'count_run_temp_dir', 'credssp.dll', 'crypt32.dll', 'cryptbase.dll', 'cryptnet.dll', 'cryptsp.dll', 'devobj.dll', 'devrtl.dll', 'dhcpcsvc.dll', 'dhcpcsvc6.dll', 'dll_for_proc', 'dnsapi.dll', 'dwmapi.dll', 'explorer.exe', 'gdi32.dll', 'gpapi.dll', 'hidden/Susp DLLs/EXEs(ldermodules)', 'ieframe.dll', 'iertutil.dll', 'imageres.dll', 'imm32.dll', 'index.dat', 'index143.dat', 'install.exe', 'interesting files accessed', 'kernel32.dll', 'lpk.dll', 'mlang.dll', 'mpr.dll', 'msasn1.dll', 'mscorrc.dll', 'mscorsvw.exe', 'msctf.dll', 'msimg32.dll', 'msvcrt.dll', 'mswsock.dll', 'ncrypt.dll', 'netapi32.dll', 'netutils.dll', 'new services', 'nlaapi.dll', 'no. of malfinds', 'no._of_child', 'no._of_envars', 'no_proc_in_hollow', 'normaliz.dll', 'nsExec.dll', 'nsi.dll', 'ntdll.dll', 'ntmarta.dll', 'ole32.dll', 'oleacc.dll', 'oleaccrc.dll', 'oleaut32.dll', 'pnrpnsp.dll', 'possible_code_injection', 'profapi.dll', 'propsys.dll', 'psapi.dll', 'pubpol4.dat', 'python.exe', 'rasadhlp.dll', 'rasapi32.dll', 'rasman.dll', 'rpcrt4.dll', 'rsaenh.dll', 'rtutils.dll', 'samcli.dll', 'schannel.dll', 'sechost.dll', 'secur32.dll', 'setupapi.dll', 'setupapi.dll.mui', 'shdocvw.dll', 'shell32.dll', 'shfolder.dll', 'shlwapi.dll', 'sortkey.nlp', 'sorttbls.nlp', 'srvcli.dll', 'sspicli.dll', 'suspicious_files', 'sxs.dll', 'tcl8.5', 'tix8.4.3', 'tk8.5', 'urlmon.dll', 'urlmon.dll.mui', 'user32.dll', 'user32.dll.mui', 'userenv.dll', 'usp10.dll', 'uxtheme.dll', 'version.dll', 'webio.dll', 'winhttp.dll', 'winhttp.dll.mui', 'wininet.dll', 'winmm.dll', 'winnsi.dll', 'winrnr.dll', 'wintrust.dll', 'wkscli.dll', 'wmpnetwk.exe', 'ws2_32.dll', 'wship6.dll', 'wsock32.dll', '', '\nCollects information about system', '\nHas access to autorun registry keys', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Associated service ', 'BootstrapperApplicationData.xml', 'BootstrapperCore.dll', 'Can access the clipboard ', 'Can bypass UAC ', 'Can create atoms ', 'Can create or start services ', 'Can create or write to files ', 'Can enumerate free disk space ', 'Can enumerate system information ', 'Can enumerat ...

# %%
list3=list1+list2
print list3
del list3[list3.index('Can bypass UAC ')]
#del list3[list3.index('Can create atoms ')]
del list3[list3.index('Can create or start services ')]
del list3[list3.index('Can create or write to files ')]
del list3[list3.index('Can enumerate free disk space ')]
del list3[list3.index('Can enumerate system information ')]
del list3[list3.index('Can identify machine time ')]
del list3[list3.index('Can identify machine version information ')]
del list3[list3.index('Can inject code to other processes ')]
del list3[list3.index('Can interact with the registry ')]
del list3[list3.index('Can query startup information ')]
del list3[list3.index('Can receive or send files from or to internet ')]
del list3[list3.index('Can track keyboard strokes ')]
del list3[list3.index('Can use antidebug techniques ')]



print list3
'''
Can bypass UAC  0 58
Can create atoms  0 20
Can create or start services  0 29
Can create or write to files  0 162
Can enumerate free disk space  0 36
Can enumerate system information  0 181
Can identify machine time  0 89
Can identify machine version information  0 94
Can inject code to other processes  0 240
Can interact with the registry  0 123
Can query startup information  0 44
Can receive or send files from or to internet  0 323
Can track keyboard strokes  0 31
Can use antidebug techniques  0 444
'''
# Out:
# ['', '\nCollects information about system', '\nHas access to autorun registry keys', '\nIdentifies installed programs', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Can access the clipboard ', 'Can bypass UAC ', 'Can create or write to files ', 'Can enumerate free disk space ', 'Can enumerate system information ', 'Can enumerate username ', 'Can identify machine time ', 'Can identify machine version information ', 'Can inject code to other processes ', 'Can interact with the registry ', 'Can query startup information ', 'Can receive or send files from or to internet ', 'Can track keyboard strokes ', 'Can use antidebug techniques ', 'FWPUCLNT.DLL', 'GoogleUpdate.e', 'IPHLPAPI.DLL', 'IPcount netscan', 'KernelBase.dll', 'KernelBase.dll.mui', 'Keylogger traces (messagehooks)', 'Mutants_accessed', 'NapiNSP.dll', 'RasPbFile', 'RpcRtRemote.dll', 'SearchFilterHo', 'SensApi.dll', 'StaticCache.dat', 'Susp DLLs (atoms)', 'Susp DLLs (atomscan)', 'Susp DLLs/EXEs (dlllist)', 'Temporary', 'Unusual process PID', 'Unusual timers.', 'WSHTCPIP.DLL', 'WininetConnectionMutex', 'WininetProxyRegistryMutex', 'WininetStartupMutex', 'Wldap32.dll', 'ZoneAttributeCacheCounterMutex', 'ZonesCacheCounterMutex', 'ZonesCounterMutex', 'ZonesLockedCacheCounterMutex', '_!MSFTHISTORY!_', 'advapi32.dll', 'apphelp.dll', 'bcrypt.dll', 'bcryptprimitives.dll', 'c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!', 'c:!users!gaurav!appdata!local!microsoft!windows!temporary', 'c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!', 'cabinet.dll', 'cfgmgr32.dll', 'clbcatq.dll', 'comctl32.dll', 'comctl32.dll.mui', 'comdlg32.dll', 'count_run_temp_dir', 'credssp.dll', 'crypt32.dll', 'cryptbase.dll', 'cryptnet.dll', 'cryptsp.dll', 'devobj.dll', 'devrtl.dll', 'dhcpcsvc.dll', 'dhcpcsvc6.dll', 'dll_for_proc', 'dnsapi.dll', 'dwmapi.dll', 'explorer.exe', 'gdi32.dll', 'gpapi.dll', 'hidden/Susp DLLs/EXEs(ldermodules)', 'ieframe.dll', 'iertutil.dll', 'imageres.dll', 'imm32.dll', 'index.dat', 'index143.dat', 'install.exe', 'interesting files accessed', 'kernel32.dll', 'lpk.dll', 'mlang.dll', 'mpr.dll', 'msasn1.dll', 'mscorrc.dll', 'mscorsvw.exe', 'msctf.dll', 'msimg32.dll', 'msvcrt.dll', 'mswsock.dll', 'ncrypt.dll', 'netapi32.dll', 'netutils.dll', 'new services', 'nlaapi.dll', 'no. of malfinds', 'no._of_child', 'no._of_envars', 'no_proc_in_hollow', 'normaliz.dll', 'nsExec.dll', 'nsi.dll', 'ntdll.dll', 'ntmarta.dll', 'ole32.dll', 'oleacc.dll', 'oleaccrc.dll', 'oleaut32.dll', 'pnrpnsp.dll', 'possible_code_injection', 'profapi.dll', 'propsys.dll', 'psapi.dll', 'pubpol4.dat', 'python.exe', 'rasadhlp.dll', 'rasapi32.dll', 'rasman.dll', 'rpcrt4.dll', 'rsaenh.dll', 'rtutils.dll', 'samcli.dll', 'schannel.dll', 'sechost.dll', 'secur32.dll', 'setupapi.dll', 'setupapi.dll.mui', 'shdocvw.dll', 'shell32.dll', 'shfolder.dll', 'shlwapi.dll', 'sortkey.nlp', 'sorttbls.nlp', 'srvcli.dll', 'sspicli.dll', 'suspicious_files', 'sxs.dll', 'tcl8.5', 'tix8.4.3', 'tk8.5', 'urlmon.dll', 'urlmon.dll.mui', 'user32.dll', 'user32.dll.mui', 'userenv.dll', 'usp10.dll', 'uxtheme.dll', 'version.dll', 'webio.dll', 'winhttp.dll', 'winhttp.dll.mui', 'wininet.dll', 'winmm.dll', 'winnsi.dll', 'winrnr.dll', 'wintrust.dll', 'wkscli.dll', 'wmpnetwk.exe', 'ws2_32.dll', 'wship6.dll', 'wsock32.dll', '', '\nCollects information about system', '\nHas access to autorun registry keys', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Associated service ', 'BootstrapperApplicationData.xml', 'BootstrapperCore.dll', 'Can access the clipboard ', 'Can bypass UAC ', 'Can create atoms ', 'Can create or start services ', 'Can create or write to files ', 'Can enumerate free disk space ', 'Can enumerate system information ', 'Can enumerat ...
# ['', '\nCollects information about system', '\nHas access to autorun registry keys', '\nIdentifies installed programs', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Can access the clipboard ', 'Can enumerate username ', 'FWPUCLNT.DLL', 'GoogleUpdate.e', 'IPHLPAPI.DLL', 'IPcount netscan', 'KernelBase.dll', 'KernelBase.dll.mui', 'Keylogger traces (messagehooks)', 'Mutants_accessed', 'NapiNSP.dll', 'RasPbFile', 'RpcRtRemote.dll', 'SearchFilterHo', 'SensApi.dll', 'StaticCache.dat', 'Susp DLLs (atoms)', 'Susp DLLs (atomscan)', 'Susp DLLs/EXEs (dlllist)', 'Temporary', 'Unusual process PID', 'Unusual timers.', 'WSHTCPIP.DLL', 'WininetConnectionMutex', 'WininetProxyRegistryMutex', 'WininetStartupMutex', 'Wldap32.dll', 'ZoneAttributeCacheCounterMutex', 'ZonesCacheCounterMutex', 'ZonesCounterMutex', 'ZonesLockedCacheCounterMutex', '_!MSFTHISTORY!_', 'advapi32.dll', 'apphelp.dll', 'bcrypt.dll', 'bcryptprimitives.dll', 'c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!', 'c:!users!gaurav!appdata!local!microsoft!windows!temporary', 'c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!', 'cabinet.dll', 'cfgmgr32.dll', 'clbcatq.dll', 'comctl32.dll', 'comctl32.dll.mui', 'comdlg32.dll', 'count_run_temp_dir', 'credssp.dll', 'crypt32.dll', 'cryptbase.dll', 'cryptnet.dll', 'cryptsp.dll', 'devobj.dll', 'devrtl.dll', 'dhcpcsvc.dll', 'dhcpcsvc6.dll', 'dll_for_proc', 'dnsapi.dll', 'dwmapi.dll', 'explorer.exe', 'gdi32.dll', 'gpapi.dll', 'hidden/Susp DLLs/EXEs(ldermodules)', 'ieframe.dll', 'iertutil.dll', 'imageres.dll', 'imm32.dll', 'index.dat', 'index143.dat', 'install.exe', 'interesting files accessed', 'kernel32.dll', 'lpk.dll', 'mlang.dll', 'mpr.dll', 'msasn1.dll', 'mscorrc.dll', 'mscorsvw.exe', 'msctf.dll', 'msimg32.dll', 'msvcrt.dll', 'mswsock.dll', 'ncrypt.dll', 'netapi32.dll', 'netutils.dll', 'new services', 'nlaapi.dll', 'no. of malfinds', 'no._of_child', 'no._of_envars', 'no_proc_in_hollow', 'normaliz.dll', 'nsExec.dll', 'nsi.dll', 'ntdll.dll', 'ntmarta.dll', 'ole32.dll', 'oleacc.dll', 'oleaccrc.dll', 'oleaut32.dll', 'pnrpnsp.dll', 'possible_code_injection', 'profapi.dll', 'propsys.dll', 'psapi.dll', 'pubpol4.dat', 'python.exe', 'rasadhlp.dll', 'rasapi32.dll', 'rasman.dll', 'rpcrt4.dll', 'rsaenh.dll', 'rtutils.dll', 'samcli.dll', 'schannel.dll', 'sechost.dll', 'secur32.dll', 'setupapi.dll', 'setupapi.dll.mui', 'shdocvw.dll', 'shell32.dll', 'shfolder.dll', 'shlwapi.dll', 'sortkey.nlp', 'sorttbls.nlp', 'srvcli.dll', 'sspicli.dll', 'suspicious_files', 'sxs.dll', 'tcl8.5', 'tix8.4.3', 'tk8.5', 'urlmon.dll', 'urlmon.dll.mui', 'user32.dll', 'user32.dll.mui', 'userenv.dll', 'usp10.dll', 'uxtheme.dll', 'version.dll', 'webio.dll', 'winhttp.dll', 'winhttp.dll.mui', 'wininet.dll', 'winmm.dll', 'winnsi.dll', 'winrnr.dll', 'wintrust.dll', 'wkscli.dll', 'wmpnetwk.exe', 'ws2_32.dll', 'wship6.dll', 'wsock32.dll', '', '\nCollects information about system', '\nHas access to autorun registry keys', '\nQueries / modifies encryption seettings', '\nQueries / modifies network settings', '\nQueries / modifies proxy settings', '\nReads information about supported languages', '!IETld!Mutex', 'Associated service ', 'BootstrapperApplicationData.xml', 'BootstrapperCore.dll', 'Can access the clipboard ', 'Can bypass UAC ', 'Can create atoms ', 'Can create or write to files ', 'Can enumerate free disk space ', 'Can enumerate system information ', 'Can enumerate username ', 'Can identify machine time ', 'Can identify machine version information ', 'Can inject code to other processes ', 'Can interact with the registry ', 'Can query startup information ', 'Can receive or send files from or to internet ', 'Can restart or shutdown the system ', 'Can track keyboard strokes ', 'Can use antidebug techniques ', 'DBWinMutex', 'ExplorerFrame.dll', 'FWPUCLNT.DLL', 'GdiPlus.dll', 'IPHLPAPI.DLL', 'IPcount netscan', 'K ...
# '\nCan bypass UAC  0 58\nCan create atoms  0 20\nCan create or start services  0 29\nCan create or write to files  0 162\nCan enumerate free disk space  0 36\nCan enumerate system information  0 181\nCan identify machine time  0 89\nCan identify machine version information  0 94\nCan inject code to other processes  0 240\nCan interact with the registry  0 123\nCan query startup information  0 44\nCan receive or send files from or to internet  0 323\nCan track keyboard strokes  0 31\nCan use antidebug techniques  0 444\n'

# %%
final_dict={}
for name in list3:
    final_dict[name]=0
print final_dict
final_dict['Y']=0
print len(final_dict)
# Out:
# {'': 0, 'System.Xml.ni.dll': 0, 'GdiPlus.dll': 0, 'netutils.dll': 0, 'imagehlp.dll': 0, 'msxml3.dll': 0, '\nIdentifies installed programs': 0, 'netmsg.dll': 0, 'mscorlib.ni.dll': 0, 'PresentationFo': 0, '!IETld!Mutex': 0, 'dwmapi.dll': 0, 'ZonesCounterMutex': 0, 'ZonesLockedCacheCounterMutex': 0, 'sqmapi.dll': 0, 'cryptsp.dll': 0, 'cabinet.dll': 0, 'mpr.dll': 0, 'msctfui.dll.mui': 0, 'nsExec.dll': 0, 'RasPbFile': 0, 'iertutil.dll': 0, '__DDrawCheckExclMode__': 0, 'c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!': 0, '__DDrawExclMode__': 0, 'crypt32.dll': 0, 'no. of malfinds': 0, 'd3d8thk.dll': 0, 'tcl8.5': 0, 'StaticCache.dat': 0, 'devobj.dll': 0, 'cryptbase.dll': 0, 'ole32.dll': 0, 'dll_for_proc': 0, 'ws2_32.dll': 0, 'nsi.dll': 0, 'Can identify machine time ': 0, 'ntdsapi.dll': 0, 'urlmon.dll.mui': 0, 'mbapreq.dll': 0, 'WindowsCodecs.dll': 0, 'tix8.4.3': 0, 'winnsi.dll': 0, 'Can bypass UAC ': 0, 'mlang.dll': 0, 'BootstrapperCore.dll': 0, 'PresentationFramework.Aero.ni.dll': 0, 'comctl32.dll.mui': 0, 'mscorsec.dll': 0, 'feclient.dll': 0, 'suspicious_files': 0, '\nQueries / modifies network settings': 0, 'c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!': 0, 'hidden/Susp DLLs/EXEs(ldermodules)': 0, 'user32.dll.mui': 0, 'msasn1.dll': 0, 'Program': 0, 'WindowsUpdate.log': 0, 'mbapreq.png': 0, 'rpcrt4.dll': 0, 'SMDiagnostics.ni.dll': 0, 'mswsock.dll': 0, 'index143.dat': 0, 'BootstrapperApplicationData.xml': 0, 'Can restart or shutdown the system ': 0, 'install.exe': 0, 'urlmon.dll': 0, 'winhttp.dll.mui': 0, '\nReads information about supported languages': 0, 'apphelp.dll': 0, '\nCollects information about system': 0, 'dnsapi.dll': 0, 'NapiNSP.dll': 0, 'mbapreq.wxl': 0, 'kernel32.dll': 0, 'imageres.dll': 0, 'Unusual process PID': 0, 'PresentationCore.ni.dll': 0, 'ntdll.dll': 0, 'Unusual timers.': 0, 'sechost.dll': 0, 'vsstrace.dll': 0, 'KernelBase.dll.mui': 0, 'riched20.dll': 0, 'SearchFilterHo': 0, 'no._of_child': 0, 'Can create atoms ': 0, 'System.Core.ni.dll': 0, 'explorer.exe': 0, 'System.Deployment.ni.dll': 0, 'dhcpcsvc6.dll': 0, 'Can access the clipboard ': 0, 'wtsapi32.dll': 0, 'Associated service ': 0, 'IPHLPAPI.DLL': 0, 'msvcr80.dll': 0, 'bcryptprimitives.dll': 0, 'pubpol4.dat': 0, 'comdlg32.dll': 0, '\nQueries / modifies proxy settings': 0, 'Can query startup information ': 0, 'rtutils.dll': 0, 'Susp DLLs (atomscan)': 0, 'count_run_temp_dir': 0, 'usp10.dll': 0, 'ncrypt.dll': 0, 'Microsoft.ApplicationInsights.dll': 0, 'shell32.dll': 0, 'uxtheme.dll': 0, 'winhttp.dll': 0, 'oleacc.dll': 0, 'profapi.dll': 0, 'samcli.dll': 0, 'Mutants_accessed': 0, 'gpapi.dll': 0, 'msxml3r.dll': 0, 'comctl32.dll': 0, 'winrnr.dll': 0, 'wpfgfx_v0300.dll': 0, 'Wldap32.dll': 0, 'index127.dat': 0, 'nlaapi.dll': 0, 'mscorjit.dll': 0, 'RpcRtRemote.dll': 0, 'Microsoft.ApplicationInsights.PersistenceChannel.dll': 0, 'shfolder.dll': 0, 'duser.dll': 0, 'Can track keyboard strokes ': 0, 'userenv.dll': 0, 'sorttbls.nlp': 0, 'user32.dll': 0, 'winspool.drv': 0, 'mbapreq.thm': 0, 'srclient.dll': 0, 'rasman.dll': 0, 'WininetProxyRegistryMutex': 0, 'gdi32.dll': 0, 'Can use antidebug techniques ': 0, 'msvcrt.dll': 0, 'Can identify machine version information ': 0, 'shlwapi.dll': 0, 'msimg32.dll': 0, 'ieframe.dll': 0, '\nQueries / modifies encryption seettings': 0, 'Microsoft.VS.PlatformInstaller.DynamicFeed.dll': 0, 'bcrypt.dll': 0, 'ManagedUx.dll': 0, 'no_proc_in_hollow': 0, 'schannel.dll': 0, 'Can interact with the registry ': 0, 'possible_code_injection': 0, 'psapi.dll': 0, 'propsys.dll': 0, 'devrtl.dll': 0, 'sspicli.dll': 0, 'wuapi.dll': 0, 'setupapi.dll.mui': 0, 'netapi32.dll': 0, 'User': 0, 'lpk.dll': 0, 'credssp.dll': 0, 'oleaccrc.dll': 0, 'msctf.dll': 0, 'Can enumerate free disk space ': 0, 'Keylogger traces (messagehooks)': 0, 'LocalizableStrings.xml': 0, 'WMINet_Utils.dll': 0, 'advapi32.dll': 0, 'WininetStartupMutex': 0, 'secur32.dll': 0, 'wsock32.dll': 0, 'Susp DLLs (atoms)': 0, 'WininetConnectionMutex': 0, 'System.Windo ...
# 259

# %%
import os
import sys
import glob
from itertools import izip
import pandas as pd
path='/home/gaurav/malware_combine_result/Results_Malware/result_'



feature_all=[]



for i in range(0,27):
    
    fp=path+str(i)
  
    with open(os.path.join(fp,'dict1'),'r')as a,open(os.path.join(fp,'dll1'),'r')as b,open(os.path.join(fp,'envars'),'r')as c,open(os.path.join(fp,'file_names'),'r')as d,open(os.path.join(fp,'mutex'),'r')as e:
              #print 'hello'
              
              count=0  
              for p,q,r,s,t in izip(a,b,c,d,e):
                    dict_1={}
                    final_dict1={}
                   
                    final_dict1=final_dict.copy()
                    p = eval(p.strip())
                    q = eval(q.strip())
                    r = eval(r.strip())
                    s = eval(s.strip())
                    t = eval(t.strip())
                    
                    dict_1=dict(dict_1.items()+p.items())
                    dict_1=dict(dict_1.items()+q.items())
                    dict_1=dict(dict_1.items()+r.items())
                    dict_1=dict(dict_1.items()+s.items())
                    dict_1=dict(dict_1.items()+t.items())
                    
                    
                   
                    for name in dict_1.keys():
                        if name in final_dict.keys():
                            final_dict1[name]=dict_1[name]
                    final_dict1['Y']= 1
                    feature_all.append(final_dict1)
#print feature_all  

print len(feature_all)


path='/home/gaurav/malware_combine_result/Results_clean/result_'





count=0 

for i in range(0,23):
    
    fp=path+str(i)
   
    
    with open(os.path.join(fp,'dict1'),'r')as a,open(os.path.join(fp,'dll1'),'r')as b,open(os.path.join(fp,'envars'),'r')as c,open(os.path.join(fp,'file_names'),'r')as d,open(os.path.join(fp,'mutex'),'r')as e:
              #print 'hello'
              
              
              for p,q,r,s,t in izip(a,b,c,d,e):
                    dict_1={}
                    final_dict1={}
                    final_dict1=final_dict.copy()
                    p = eval(p.strip())
                    q = eval(q.strip())
                    r = eval(r.strip())
                    s = eval(s.strip())
                    t = eval(t.strip())
                    
                    dict_1=dict(dict_1.items()+p.items())
                    dict_1=dict(dict_1.items()+q.items())
                    dict_1=dict(dict_1.items()+r.items())
                    dict_1=dict(dict_1.items()+s.items())
                    dict_1=dict(dict_1.items()+t.items())
                    
                    
                   
                    for name in dict_1.keys():
                        if name in final_dict.keys():
                            final_dict1[name]=dict_1[name]
                    final_dict1['Y']=0
                    feature_all.append(final_dict1)

                    count+=1
                    #print count
                    #if count>490:
                        #break
                    
                    
                    
    #if count>490:
            #break
# Out:
# 1766

# %%
df7=pd.DataFrame.from_records(feature_all).fillna(0)
print df7.shape
print df7.var().sort_values()
'''
df7=df7.drop('Mutants_accessed',axis=1)
df7=df7.drop('Keylogger traces (messagehooks)',axis=1)
df7=df7.drop('\nHas access to autorun registry keys',axis=1)
df7=df7.drop('interesting files accessed',axis=1)
df7=df7.drop('\nCollects information about system',axis=1)
df7=df7.drop('no._of_child',axis=1)
df7=df7.drop('Susp DLLs/EXEs (dlllist)',axis=1)
df7=df7.drop('possible_code_injection',axis=1)
df7=df7.drop('dll_for_proc',axis=1)
df7=df7.drop('suspicious_files',axis=1)
df7=df7.drop('hidden/Susp DLLs/EXEs(ldermodules)',axis=1)
df7=df7.drop('Associated service ',axis=1)
df7=df7.drop('count_run_temp_dir',axis=1)
df7=df7.drop('\nReads information about supported languages',axis=1)
df7=df7.drop('IPcount netscan',axis=1)
df7=df7.drop('no._of_envars',axis=1)
df7=df7.drop('no. of malfinds',axis=1)
df7=df7.drop('\nQueries / modifies proxy settings',axis=1)
df7=df7.drop('new services',axis=1)

'''
# Out:
# (3310, 259)
# Unusual process PID                                  0.000000
# \nIdentifies installed programs                      0.003924
# msctfui.dll                                          0.022729
# PresentationNative_v0300.dll                         0.023017
# Can access the clipboard                             0.023017
# System.Xml.Linq.ni.dll                               0.023304
# Can restart or shutdown the system                   0.023304
# Can create atoms                                     0.024225
# SMDiagnostics.ni.dll                                 0.024741
# System.Deployment.ni.dll                             0.024741
# System.Runtime.Serialization.ni.dll                  0.024741
# WMINet_Utils.dll                                     0.025028
# System.Management.ni.dll                             0.025314
# PresentationFramework.Aero.ni.dll                    0.025601
# d3d8thk.dll                                          0.025887
# d3d9.dll                                             0.025887
# wuapi.dll                                            0.026173
# vsstrace.dll                                         0.029591
# vssapi.dll                                           0.029591
# spp.dll                                              0.029591
# srclient.dll                                         0.029591
# feclient.dll                                         0.031008
# Can enumerate username                               0.035031
# Can enumerate free disk space                        0.048704
# Can track keyboard strokes                           0.071344
# \nQueries / modifies network settings                0.088387
# python.exe                                           0.111272
# SearchFilterHo                                       0.146714
# Susp DLLs (atomscan)                                 0.168837
# Susp DLLs (atoms)                                    0.168837
#                                                      ...
# Can query startup information                        0.251648
# count_run_temp_dir                                   0.292725
# no_proc_in_hollow                                    0.361568
# Associated service                                   0.399599
# \nReads information about supported languages        0.650276
# Unusual timers.                                      0.796264
# Can identify machine version information             0.935247
# Can interact with the registry                       1.038672
# Can create or write to files                         1.120424
# no._of_envars                                        1.803370
# no. of malfinds                                      1.831337
# \nQueries / modifies proxy settings                  1.843034
# Can identify machine time                            2.102423
# IPcount netscan                                      2.387682
# new services                                         3.224176
# Can enumerate system information                     3.666809
# no._of_child                                         6.805221
# Mutants_accessed                                     9.875905
# Can inject code to other processes                  11.347548
# Keylogger traces (messagehooks)                     14.184608
# \nHas access to autorun registry keys               22.456924
# interesting files accessed                          24.250061
# Can use antidebug techniques                        38.264581
# Can receive or send files from or to internet      141.788184
# \nCollects information about system                149.842357
# Susp DLLs/EXEs (dlllist)                           216.667721
# possible_code_injection                            249.657827
# dll_for_proc                                       698.398454
# suspicious_files                                  2005.963312
# hidden/Susp DLLs/EXEs(ldermodules)                2176.428729
# Length: 259, dtype: float64
# "\ndf7=df7.drop('Mutants_accessed',axis=1)\ndf7=df7.drop('Keylogger traces (messagehooks)',axis=1)\ndf7=df7.drop('\nHas access to autorun registry keys',axis=1)\ndf7=df7.drop('interesting files accessed',axis=1)\ndf7=df7.drop('\nCollects information about system',axis=1)\ndf7=df7.drop('no._of_child',axis=1)\ndf7=df7.drop('Susp DLLs/EXEs (dlllist)',axis=1)\ndf7=df7.drop('possible_code_injection',axis=1)\ndf7=df7.drop('dll_for_proc',axis=1)\ndf7=df7.drop('suspicious_files',axis=1)\ndf7=df7.drop('hidden/Susp DLLs/EXEs(ldermodules)',axis=1)\ndf7=df7.drop('Associated service ',axis=1)\ndf7=df7.drop('count_run_temp_dir',axis=1)\ndf7=df7.drop('\nReads information about supported languages',axis=1)\ndf7=df7.drop('IPcount netscan',axis=1)\ndf7=df7.drop('no._of_envars',axis=1)\ndf7=df7.drop('no. of malfinds',axis=1)\ndf7=df7.drop('\nQueries / modifies proxy settings',axis=1)\ndf7=df7.drop('new services',axis=1)\n\n"

# %%
for name in df7:
    print name
# Out:
# Collects information about system
#
# Has access to autorun registry keys
#
# Identifies installed programs
#
# Queries / modifies encryption seettings
#
# Queries / modifies network settings
#
# Queries / modifies proxy settings
#
# Reads information about supported languages
# !IETld!Mutex
# Associated service
# BootstrapperApplicationData.xml
# BootstrapperCore.dll
# Can access the clipboard
# Can bypass UAC
# Can create atoms
# Can create or write to files
# Can enumerate free disk space
# Can enumerate system information
# Can enumerate username
# Can identify machine time
# Can identify machine version information
# Can inject code to other processes
# Can interact with the registry
# Can query startup information
# Can receive or send files from or to internet
# Can restart or shutdown the system
# Can track keyboard strokes
# Can use antidebug techniques
# DBWinMutex
# ExplorerFrame.dll
# FWPUCLNT.DLL
# GdiPlus.dll
# GoogleUpdate.e
# IPHLPAPI.DLL
# IPcount netscan
# KernelBase.dll
# KernelBase.dll.mui
# Keylogger traces (messagehooks)
# LocalizableStrings.xml
# ManagedUx.dll
# Microsoft.ApplicationInsights.PersistenceChannel.dll
# Microsoft.ApplicationInsights.dll
# Microsoft.Diagnostics.Tracing.EventSource.dll
# Microsoft.VS.PlatformInstaller.DynamicFeed.dll
# Microsoft.VisualStudio.Telemetry.Net35.dll
# Mutants_accessed
# NapiNSP.dll
# Newtonsoft.Json.dll
# PresentationCore.ni.dll
# PresentationFo
# PresentationFramework.Aero.ni.dll
# PresentationFramework.ni.dll
# PresentationNative_v0300.dll
# Program
# RasPbFile
# RpcRtRemote.dll
# SMDiagnostics.ni.dll
# SearchFilterHo
# SensApi.dll
# StaticCache.dat
# Susp DLLs (atoms)
# Susp DLLs (atomscan)
# Susp DLLs/EXEs (dlllist)
# System.Configuration.ni.dll
# System.Core.ni.dll
# System.Deployment.ni.dll
# System.Drawing.ni.dll
# System.Management.ni.dll
# System.Runtime.Serialization.ni.dll
# System.Threading.dll
# System.Windows.Forms.ni.dll
# System.Xml.Linq.ni.dll
# System.Xml.ni.dll
# System.ni.dll
# Temporary
# Unusual process PID
# Unusual timers.
# User
# WMINet_Utils.dll
# WSHTCPIP.DLL
# WindowsBase.ni.dll
# WindowsCodecs.dll
# WindowsUpdate.log
# WindowsUpdateTracingMutex
# WininetConnectionMutex
# WininetProxyRegistryMutex
# WininetStartupMutex
# Wldap32.dll
# Y
# ZoneAttributeCacheCounterMutex
# ZonesCacheCounterMutex
# ZonesCounterMutex
# ZonesLockedCacheCounterMutex
# _!MSFTHISTORY!_
# __DDrawCheckExclMode__
# __DDrawExclMode__
# advapi32.dll
# apphelp.dll
# atl.dll
# bcrypt.dll
# bcryptprimitives.dll
# c:!users!gaurav!appdata!local!microsoft!windows!history!history.ie5!
# c:!users!gaurav!appdata!local!microsoft!windows!temporary
# c:!users!gaurav!appdata!roaming!microsoft!windows!cookies!
# cabinet.dll
# cfgmgr32.dll
# chrome.exe
# clbcatq.dll
# comctl32.dll
# comctl32.dll.mui
# comdlg32.dll
# count_run_temp_dir
# credssp.dll
# crypt32.dll
# cryptbase.dll
# cryptnet.dll
# cryptsp.dll
# d3d8thk.dll
# d3d9.dll
# devobj.dll
# devrtl.dll
# dhcpcsvc.dll
# dhcpcsvc6.dll
# dll_for_proc
# dnsapi.dll
# dui70.dll
# duser.dll
# dwmapi.dll
# explorer.exe
# fastprox.dll
# feclient.dll
# gdi32.dll
# gpapi.dll
# hidden/Susp DLLs/EXEs(ldermodules)
# ieframe.dll
# iertutil.dll
# imagehlp.dll
# imageres.dll
# imm32.dll
# index.dat
# index127.dat
# index143.dat
# install.exe
# interesting files accessed
# kernel32.dll
# lpk.dll
# mbahost.dll
# mbapreq.dll
# mbapreq.png
# mbapreq.thm
# mbapreq.wxl
# mlang.dll
# mpr.dll
# msasn1.dll
# mscoree.dll
# mscoreei.dll
# mscorjit.dll
# mscorlib.ni.dll
# mscorrc.dll
# mscorsec.dll
# mscorsvw.exe
# mscorwks.dll
# msctf.dll
# msctfui.dll
# msctfui.dll.mui
# msi.dll
# msimg32.dll
# msvcr80.dll
# msvcrt.dll
# mswsock.dll
# msxml3.dll
# msxml3r.dll
# ncrypt.dll
# netapi32.dll
# netmsg.dll
# netutils.dll
# new services
# nlaapi.dll
# no. of malfinds
# no._of_child
# no._of_envars
# no_proc_in_hollow
# normaliz.dll
# nsExec.dll
# nsi.dll
# ntdll.dll
# ntdsapi.dll
# ntmarta.dll
# ole32.dll
# oleacc.dll
# oleaccrc.dll
# oleaut32.dll
# pnrpnsp.dll
# possible_code_injection
# profapi.dll
# propsys.dll
# psapi.dll
# pubpol4.dat
# python.exe
# rasadhlp.dll
# rasapi32.dll
# rasman.dll
# riched20.dll
# rpcrt4.dll
# rsaenh.dll
# rtutils.dll
# samcli.dll
# schannel.dll
# sechost.dll
# secur32.dll
# setupapi.dll
# setupapi.dll.mui
# shdocvw.dll
# shell32.dll
# shfolder.dll
# shlwapi.dll
# sortkey.nlp
# sorttbls.nlp
# spp.dll
# sqmapi.dll
# srclient.dll
# srvcli.dll
# sspicli.dll
# suspicious_files
# sxs.dll
# tcl8.5
# tix8.4.3
# tk8.5
# urlmon.dll
# urlmon.dll.mui
# user32.dll
# user32.dll.mui
# userenv.dll
# usp10.dll
# uxtheme.dll
# version.dll
# vssapi.dll
# vsstrace.dll
# wbemcomn.dll
# wbemprox.dll
# wbemsvc.dll
# webio.dll
# winhttp.dll
# winhttp.dll.mui
# wininet.dll
# winmm.dll
# winnsi.dll
# winrnr.dll
# winspool.drv
# wintrust.dll
# wkscli.dll
# wmiutils.dll
# wmpnetwk.exe
# wpfgfx_v0300.dll
# ws2_32.dll
# wship6.dll
# wsock32.dll
# wtsapi32.dll
# wuapi.dll

# %%
import hashlib
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score
from sklearn.cross_validation import train_test_split
import timeit
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.svm import SVC
from sklearn.grid_search import RandomizedSearchCV
from sklearn.grid_search import GridSearchCV
from sklearn.feature_selection import VarianceThreshold
from sklearn import svm
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
df3=df7
print df3.shape
# Out:
# (3310, 259)

# %%
########pCA-------####################
for k in range(1,2,1):
    val=0
    for n in range(1,20):
        from sklearn.preprocessing import StandardScaler
        from sklearn.metrics import precision_recall_fscore_support
        
        train, test = train_test_split(df3, test_size = 0.3)
        X_train=pd.DataFrame(train)

        Y_train=list(X_train['Y'])#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
        
                        
        
        X_train=X_train.drop('Y',axis=1)
        #X_train=pd.DataFrame(X_train[n])
        X_train = StandardScaler().fit_transform(X_train)


        X_test=pd.DataFrame(test)
        #print len(X_train)

        Y_test=list(X_test['Y'])
        X_test=X_test.drop('Y',axis=1)
        #X_test=pd.DataFrame(X_test[n])

        X_test = StandardScaler().fit_transform(X_test)

        #print len(X_test)   
        ##############################################
        from sklearn.pipeline import Pipeline
        from sklearn.decomposition import PCA
        from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
        from sklearn.tree import DecisionTreeClassifier

        # fits PCA, transforms data and fits the decision tree classifier
        # on the transformed data
        #pipe = Pipeline([('pca', PCA(n_components=1)),
        #                 ('tree', DecisionTreeClassifier())])
        

        #pipe.fit(X_train, Y_train)
        #pca = PCA(20)

        #pca.fit(X_train)
        #print(pca.components_)
        #print(pca.explained_variance_)
        #print pipe.score(X_test,Y_test)
        #val=val+ pipe.score(X_test,Y_test)
        clf = DecisionTreeClassifier(random_state=0)
        #clf=svm.SVC()
        #clf = clf.fit(X_train,Y_train)
            #print clf.feature_importances_
        
        clf = clf.fit(X_train,Y_train)
        Y_pred = clf.predict(X_test)
        #clf = DecisionTreeClassifier(random_state=0)

        
            #print clf.feature_importances_

        #Y_pred = clf.predict(X_test)
        
        print clf.score(X_test,Y_test)
        import numpy as np
        import matplotlib.pyplot as plt
        from sklearn.metrics import confusion_matrix
        from mlxtend.plotting import plot_confusion_matrix
        cm = confusion_matrix(Y_test, 
                              Y_pred)
        fig, ax = plot_confusion_matrix(conf_mat=cm)
        plt.figure(figsize=(1,1))


        plt.show()
        '''
        if clf.score(X_test,Y_test)>0.7:
                import numpy as np
                import pandas as pd
                print n
                print clf.score(X_test,Y_test)
                print precision_recall_fscore_support(Y_test, Y_pred, average='macro')
                print df0[n].mean()
                print df1[n].mean()
                d = {n+'\n one' : df0[n],'two' : df1[n]}
                     


               

                df = pd.DataFrame(d)
                df.plot(style=['o','rx'],figsize=(20,10))
                df7=df7.drop(n,axis=1)
    #print 'k value:' +str(k) +'   '+str(val/30)
    '''
# Out:
# 0.9859013091641491
# 0.9909365558912386
# 0.9818731117824774
# 0.9536757301107754
# 1.0
# 0.9879154078549849
# 0.9939577039274925
# 0.9939577039274925
# 0.9939577039274925
# 0.9697885196374623
# 0.9939577039274925
# 0.9979859013091642
# 0.9969788519637462
# 0.9929506545820745
# 0.9919436052366566
# 0.9979859013091642
# 0.9939577039274925
# 0.9869083585095669
# 0.9808660624370594

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
cm = confusion_matrix(Y_test, 
                      Y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm)
plt.figure(figsize=(1,1))


plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    print corr_matrix
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if corr_matrix.iloc[i, j] >= threshold:
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                print colname
                if colname in dataset.columns:
                    
                    if colname=='Y':
                        continue
                    else:
                       
                        del dataset[colname] # deleting the column from the dataset

    print col_corr
    return dataset

# %%
df3=df7
mylist=correlation(df3,0.9)
#print
#print mylist

#print mylist['Y']
for name1 in mylist:
    print name1
# Out:
#                                                          \
#                                                1.000000
# \nCollects information about system            0.708632
# \nHas access to autorun registry keys          0.012842
# \nIdentifies installed programs               -0.049227
# \nQueries / modifies network settings         -0.193854
# \nQueries / modifies proxy settings           -0.097856
# \nReads information about supported languages -0.118441
# !IETld!Mutex                                   0.724092
# Associated service                            -0.034148
# Can access the clipboard                       0.008349
# Can bypass UAC                                -0.035857
# Can create atoms                              -0.008510
# Can create or write to files                   0.671383
# Can enumerate free disk space                 -0.016227
# Can enumerate username                        -0.026602
# Can restart or shutdown the system             0.009655
# Can track keyboard strokes                    -0.032033
# IPcount netscan                               -0.396442
# KernelBase.dll                                 0.690472
# KernelBase.dll.mui                             0.716515
# Keylogger traces (messagehooks)               -0.039201
# Mutants_accessed                               0.050012
# PresentationFramework.Aero.ni.dll             -0.008766
# SearchFilterHo                                 0.363465
# StaticCache.dat                                0.695713
# Susp DLLs (atoms)                             -0.103203
# Susp DLLs/EXEs (dlllist)                       0.613235
# Unusual process PID                                 NaN
# Unusual timers.                               -0.434667
# Y                                              0.733554
# comdlg32.dll                                   0.712862
# count_run_temp_dir                             0.568076
# dll_for_proc                                  -0.047821
# explorer.exe                                   0.631729
# feclient.dll                                  -0.007675
# hidden/Susp DLLs/EXEs(ldermodules)            -0.214732
# interesting files accessed                     0.040897
# new services                                  -0.135560
# no. of malfinds                                0.004753
# no._of_child                                  -0.124369
# no._of_envars                                 -0.214008
# no_proc_in_hollow                             -0.548829
# possible_code_injection                       -0.013219
# python.exe                                     0.557311
# suspicious_files                              -0.197736
# tcl8.5                                         0.647959
#
#                                                \nCollects information about system  \
#                                                                           0.708632
# \nCollects information about system                                       1.000000
# \nHas access to autorun registry keys                                    -0.035330
# \nIdentifies installed programs                                          -0.015856
# \nQueries / modifies network settings                                    -0.046247
# \nQueries / modifies proxy settings                                       0.182257
# \nReads information about supported languages                            -0.248747
# !IETld!Mutex                                                              0.839704
# Associated service                                                       -0.001158
# Can access the clipboard                                                 -0.091832
# Can bypass UAC                                                           -0.066772
# Can create atoms                                                         -0.138524
# Can create or write to files                                              0.662025
# Can enumerate free disk space                                            -0.134009
# Can enumerate username                                                   -0.023152
# Can restart or shutdown the system                                       -0.104807
# Can track keyboard strokes                                               -0.142773
# IPcount netscan                                                          -0.309804
# KernelBase.dll                                                            0.701629
# KernelBase.dll.mui                                                        0.871869
# Keylogger traces (messagehooks)                                          -0.023207
# Mutants_accessed                                                          0.298591
# PresentationFramework.Aero.ni.dll                                         0.254583
# SearchFilterHo                                                            0.446596
# StaticCache.dat                                                           0.576693
# Susp DLLs (atoms)                                                        -0.046047
# Susp DLLs/EXEs (dlllist)                                                  0.674346
# Unusual process PID                                                            NaN
# Unusual timers.                                                          -0.481244
# Y                                                                         0.808478
# comdlg32.dll                                                              0.719922
# count_run_temp_dir                                                        0.551786
# dll_for_proc                                                              0.090487
# explorer.exe                                                              0.697157
# feclient.dll                                                              0.197225
# hidden/Susp DLLs/EXEs(ldermodules)                                       -0.090122
# interesting files accessed                                                0.303164
# new services                                                             -0.073386
# no. of malfinds                                                           0.058094
# no._of_child                                                             -0.091247
# no._of_envars                                                            -0.254727
# no_proc_in_hollow                                                        -0.606914
# possible_code_injection                                                   0.072202
# python.exe                                                                0.517892
# suspicious_files                                                         -0.167832
# tcl8.5                                                                    0.665468
#
#                                                \nHas access to autorun registry keys  \
#                                                                             0.012842
# \nCollects information about system                                        -0.035330
# \nHas access to autorun registry keys                                       1.000000
# \nIdentifies installed programs                                             0.017190
# \nQueries / modifies network settings                                      -0.004160
# \nQueries / modifies proxy settings                                         0.215882
# \nReads information about supported languages                               0.393920
# !IETld!Mutex                                                               -0.146018
# Associated service                                                         -0.002199
# Can access the clipboard                                                    0.346312
# Can bypass UAC                                                              0.149202
# Can create atoms                                                            0.098282
# Can create or write to files                                               -0.003487
# Can enumerate free disk space                                               0.331325
# Can enumerate username                                                      0.111684
# Can restart or shutdown the system                                          0.385994
# Can track keyboard strokes                                                  0.103314
# IPcount netscan                                                             0.155410
# KernelBase.dll                                                             -0.021010
# KernelBase.dll.mui                                                         -0.068640
# Keylogger traces (messagehooks)                                             0.004303
# Mutants_accessed                                                            0.189166
# PresentationFramework.Aero.ni.dll                                           0.007179
# SearchFilterHo                                                             -0.117345
# StaticCache.dat                                                             0.122187
# Susp DLLs (atoms)                                                           0.245758
# Susp DLLs/EXEs (dlllist)                                                    0.131098
# Unusual process PID                                                              NaN
# Unusual timers.                                                             0.238643
# Y                                                                          -0.197143
# comdlg32.dll                                                               -0.067032
# count_run_temp_dir                                                          0.293849
# dll_for_proc                                                                0.237860
# explorer.exe                                                               -0.076027
# feclient.dll                                                                0.034918
# hidden/Susp DLLs/EXEs(ldermodules)                                          0.221698
# interesting files accessed                                                  0.162814
# new services                                                                0.098053
# no. of malfinds                                                             0.320809
# no._of_child                                                                0.170273
# no._of_envars                                                               0.255301
# no_proc_in_hollow                                                           0.238745
# possible_code_injection                                                     0.134259
# python.exe                                                                  0.148847
# suspicious_files                                                            0.175695
# tcl8.5                                                                      0.018157
#
#                                                \nIdentifies installed programs  \
#                                                                      -0.049227
# \nCollects information about system                                  -0.015856
# \nHas access to autorun registry keys                                 0.017190
# \nIdentifies installed programs                                       1.000000
# \nQueries / modifies network settings                                -0.005045
# \nQueries / modifies proxy settings                                   0.025578
# \nReads information about supported languages                         0.030754
# !IETld!Mutex                                                         -0.018469
# Associated service                                                   -0.000791
# Can access the clipboard                                             -0.005245
# Can bypass UAC                                                       -0.005958
# Can create atoms                                                     -0.005113
# Can create or write to files                                         -0.036415
# Can enumerate free disk space                                        -0.006426
# Can enumerate username                                               -0.005505
# Can restart or shutdown the system                                   -0.005280
# Can track keyboard strokes                                           -0.005347
# IPcount netscan                                                       0.054554
# KernelBase.dll                                                       -0.008513
# KernelBase.dll.mui                                                   -0.043569
# Keylogger traces (messagehooks)                                      -0.001736
# Mutants_accessed                                                      0.065515
# PresentationFramework.Aero.ni.dll                                    -0.005547
# SearchFilterHo                                                        0.015742
# StaticCache.dat                                                      -0.009199
# Susp DLLs (atoms)                                                     0.060934
# Susp DLLs/EXEs (dlllist)                                             -0.017858
# Unusual process PID                                                        NaN
# Unusual timers.                                                       0.073898
# Y                                                                    -0.036110
# comdlg32.dll                                                         -0.001194
# count_run_temp_dir                                                   -0.044863
# dll_for_proc                                                          0.055928
# explorer.exe                                                          0.017555
# feclient.dll                                                         -0.006141
# hidden/Susp DLLs/EXEs(ldermodules)                                    0.092813
# interesting files accessed                                            0.000499
# new services                                                          0.336363
# no. of malfinds                                                       0.058874
# no._of_child                                                          0.020290
# no._of_envars                                                         0.058810
# no_proc_in_hollow                                                     0.062768
# possible_code_injection                                               0.038095
# python.exe                                                            0.012907
# suspicious_files                                                      0.035921
# tcl8.5                                                                0.019847
#
#                                                \nQueries / modifies network settings  \
#                                                                            -0.193854
# \nCollects information about system                                        -0.046247
# \nHas access to autorun registry keys                                      -0.004160
# \nIdentifies installed programs                                            -0.005045
# \nQueries / modifies network settings                                       1.000000
# \nQueries / modifies proxy settings                                         0.300370
# \nReads information about supported languages                              -0.012660
# !IETld!Mutex                                                               -0.126740
# Associated service                                                          0.165345
# Can access the clipboard                                                   -0.023210
# Can bypass UAC                                                              0.065669
# Can create atoms                                                           -0.022623
# Can create or write to files                                               -0.136165
# Can enumerate free disk space                                              -0.023827
# Can enumerate username                                                      0.127708
# Can restart or shutdown the system                                         -0.023362
# Can track keyboard strokes                                                 -0.023662
# IPcount netscan                                                             0.185477
# KernelBase.dll                                                             -0.208808
# KernelBase.dll.mui                                                         -0.192786
# Keylogger traces (messagehooks)                                             0.058172
# Mutants_accessed                                                            0.044712
# PresentationFramework.Aero.ni.dll                                          -0.024547
# SearchFilterHo                                                              0.008617
# StaticCache.dat                                                            -0.177784
# Susp DLLs (atoms)                                                          -0.027236
# Susp DLLs/EXEs (dlllist)                                                   -0.050359
# Unusual process PID                                                              NaN
# Unusual timers.                                                             0.229022
# Y                                                                          -0.159784
# comdlg32.dll                                                               -0.166395
# count_run_temp_dir                                                         -0.179725
# dll_for_proc                                                               -0.048045
# explorer.exe                                                               -0.163252
# feclient.dll                                                               -0.027175
# hidden/Susp DLLs/EXEs(ldermodules)                                          0.033540
# interesting files accessed                                                  0.035856
# new services                                                               -0.020883
# no. of malfinds                                                             0.373935
# no._of_child                                                                0.203171
# no._of_envars                                                               0.300346
# no_proc_in_hollow                                                           0.134048
# possible_code_injection                                                     0.558043
# python.exe                                                                  0.038827
# suspicious_files                                                            0.122997
# tcl8.5                                                                      0.020355
#
#                                                \nQueries / modifies proxy settings  \
#                                                                          -0.097856
# \nCollects information about system                                       0.182257
# \nHas access to autorun registry keys                                     0.215882
# \nIdentifies installed programs                                           0.025578
# \nQueries / modifies network settings                                     0.300370
# \nQueries / modifies proxy settings                                       1.000000
# \nReads information about supported languages                             0.441898
# !IETld!Mutex                                                             -0.137819
# Associated service                                                       -0.006907
# Can access the clipboard                                                  0.052494
# Can bypass UAC                                                            0.176209
# Can create atoms                                                          0.076912
# Can create or write to files                                             -0.116231
# Can enumerate free disk space                                             0.089125
# Can enumerate username                                                    0.263523
# Can restart or shutdown the system                                        0.009298
# Can track keyboard strokes                                                0.081639
# IPcount netscan                                                           0.498117
# KernelBase.dll                                                           -0.110458
# KernelBase.dll.mui                                                       -0.046808
# Keylogger traces (messagehooks)                                           0.039211
# Mutants_accessed                                                          0.847479
# PresentationFramework.Aero.ni.dll                                         0.570659
# SearchFilterHo                                                           -0.092069
# StaticCache.dat                                                          -0.204853
# Susp DLLs (atoms)                                                         0.330841
# Susp DLLs/EXEs (dlllist)                                                  0.153225
# Unusual process PID                                                            NaN
# Unusual timers.                                                           0.384220
# Y                                                                        -0.315398
# comdlg32.dll                                                             -0.291392
# count_run_temp_dir                                                        0.282387
# dll_for_proc                                                              0.573902
# explorer.exe                                                             -0.293650
# feclient.dll                                                              0.520285
# hidden/Susp DLLs/EXEs(ldermodules)                                        0.475323
# interesting files accessed                                                0.711312
# new services                                                              0.199745
# no. of malfinds                                                           0.489149
# no._of_child                                                              0.130880
# no._of_envars                                                             0.399949
# no_proc_in_hollow                                                         0.290887
# possible_code_injection                                                   0.258112
# python.exe                                                                0.112731
# suspicious_files                                                          0.336520
# tcl8.5                                                                    0.000131
#
#                                                \nReads information about supported languages  \
#                                                                                    -0.118441
# \nCollects information about system                                                -0.248747
# \nHas access to autorun registry keys                                               0.393920
# \nIdentifies installed programs                                                     0.030754
# \nQueries / modifies network settings                                              -0.012660
# \nQueries / modifies proxy settings                                                 0.441898
# \nReads information about supported languages                                       1.000000
# !IETld!Mutex                                                                       -0.453851
# Associated service                                                                  0.029634
# Can access the clipboard                                                            0.207844
# Can bypass UAC                                                                      0.280446
# Can create atoms                                                                    0.298904
# Can create or write to files                                                       -0.232384
# Can enumerate free disk space                                                       0.304346
# Can enumerate username                                                              0.269800
# Can restart or shutdown the system                                                  0.210463
# Can track keyboard strokes                                                          0.309816
# IPcount netscan                                                                     0.568854
# KernelBase.dll                                                                     -0.052150
# KernelBase.dll.mui                                                                 -0.223418
# Keylogger traces (messagehooks)                                                     0.064497
# Mutants_accessed                                                                    0.443893
# PresentationFramework.Aero.ni.dll                                                   0.291522
# SearchFilterHo                                                                     -0.180614
# StaticCache.dat                                                                     0.112562
# Susp DLLs (atoms)                                                                   0.479339
# Susp DLLs/EXEs (dlllist)                                                            0.039118
# Unusual process PID                                                                      NaN
# Unusual timers.                                                                     0.639825
# Y                                                                                  -0.541798
# comdlg32.dll                                                                       -0.329043
# count_run_temp_dir                                                                  0.390023
# dll_for_proc                                                                        0.629153
# explorer.exe                                                                       -0.401920
# feclient.dll                                                                        0.329244
# hidden/Susp DLLs/EXEs(ldermodules)                                                  0.517319
# interesting files accessed                                                          0.419662
# new services                                                                        0.288518
# no. of malfinds                                                                     0.561631
# no._of_child                                                                        0.164215
# no._of_envars                                                                       0.650757
# no_proc_in_hollow                                                                   0.587406
# possible_code_injection                                                             0.137838
# python.exe                                                                          0.182418
# suspicious_files                                                                    0.433912
# tcl8.5                                                                              0.033614
#
#                                                !IETld!Mutex  \
#                                                    0.724092
# \nCollects information about system                0.839704
# \nHas access to autorun registry keys             -0.146018
# \nIdentifies installed programs                   -0.018469
# \nQueries / modifies network settings             -0.126740
# \nQueries / modifies proxy settings               -0.137819
# \nReads information about supported languages     -0.453851
# !IETld!Mutex                                       1.000000
# Associated service                                -0.026285
# Can access the clipboard                          -0.138249
# Can bypass UAC                                    -0.149825
# Can create atoms                                  -0.138664
# Can create or write to files                       0.718106
# Can enumerate free disk space                     -0.158443
# Can enumerate username                            -0.104976
# Can restart or shutdown the system                -0.167509
# Can track keyboard strokes                        -0.134458
# IPcount netscan                                   -0.576820
# KernelBase.dll                                     0.704129
# KernelBase.dll.mui                                 0.816928
# Keylogger traces (messagehooks)                   -0.057712
# Mutants_accessed                                   0.054071
# PresentationFramework.Aero.ni.dll                 -0.119743
# SearchFilterHo                                     0.473966
# StaticCache.dat                                    0.708730
# Susp DLLs (atoms)                                 -0.243523
# Susp DLLs/EXEs (dlllist)                           0.576115
# Unusual process PID                                     NaN
# Unusual timers.                                   -0.690304
# Y                                                  0.952999
# comdlg32.dll                                       0.856197
# count_run_temp_dir                                 0.316281
# dll_for_proc                                      -0.258345
# explorer.exe                                       0.840258
# feclient.dll                                      -0.141935
# hidden/Susp DLLs/EXEs(ldermodules)                -0.377531
# interesting files accessed                        -0.105952
# new services                                      -0.208060
# no. of malfinds                                   -0.200469
# no._of_child                                      -0.160721
# no._of_envars                                     -0.480258
# no_proc_in_hollow                                 -0.765069
# possible_code_injection                           -0.079476
# python.exe                                         0.428980
# suspicious_files                                  -0.361289
# tcl8.5                                             0.619285
#
#                                                Associated service   \
#                                                          -0.034148
# \nCollects information about system                      -0.001158
# \nHas access to autorun registry keys                    -0.002199
# \nIdentifies installed programs                          -0.000791
# \nQueries / modifies network settings                     0.165345
# \nQueries / modifies proxy settings                      -0.006907
# \nReads information about supported languages             0.029634
# !IETld!Mutex                                             -0.026285
# Associated service                                        1.000000
# Can access the clipboard                                  0.018420
# Can bypass UAC                                            0.124635
# Can create atoms                                         -0.003547
# Can create or write to files                              0.003193
# Can enumerate free disk space                             0.010706
# Can enumerate username                                   -0.003819
# Can restart or shutdown the system                        0.018259
# Can track keyboard strokes                               -0.003709
# IPcount netscan                                           0.014020
# KernelBase.dll                                           -0.034798
# KernelBase.dll.mui                                       -0.030223
# Keylogger traces (messagehooks)                          -0.001205
# Mutants_accessed                                          0.080588
# PresentationFramework.Aero.ni.dll                        -0.003848
# SearchFilterHo                                           -0.006554
# StaticCache.dat                                          -0.035496
# Susp DLLs (atoms)                                        -0.006597
# Susp DLLs/EXEs (dlllist)                                 -0.035122
# Unusual process PID                                            NaN
# Unusual timers.                                           0.032510
# Y                                                        -0.025049
# comdlg32.dll                                             -0.028028
# count_run_temp_dir                                       -0.031121
# dll_for_proc                                             -0.009829
# explorer.exe                                             -0.028849
# feclient.dll                                             -0.004260
# hidden/Susp DLLs/EXEs(ldermodules)                       -0.011654
# interesting files accessed                                0.021413
# new services                                              0.009683
# no. of malfinds                                          -0.023455
# no._of_child                                              0.124398
# no._of_envars                                            -0.011536
# no_proc_in_hollow                                         0.026845
# possible_code_injection                                  -0.014238
# python.exe                                               -0.061272
# suspicious_files                                          0.013337
# tcl8.5                                                   -0.039846
#
#                                                Can access the clipboard   \
#                                                                 0.008349
# \nCollects information about system                            -0.091832
# \nHas access to autorun registry keys                           0.346312
# \nIdentifies installed programs                                -0.005245
# \nQueries / modifies network settings                          -0.023210
# \nQueries / modifies proxy settings                             0.052494
# \nReads information about supported languages                   0.207844
# !IETld!Mutex                                                   -0.138249
# Associated service                                              0.018420
# Can access the clipboard                                        1.000000
# Can bypass UAC                                                  0.058254
# Can create atoms                                                0.386017
# Can create or write to files                                    0.152103
# Can enumerate free disk space                                   0.701546
# Can enumerate username                                          0.027883
# Can restart or shutdown the system                              0.445457
# Can track keyboard strokes                                      0.475060
# IPcount netscan                                                 0.014539
# KernelBase.dll                                                 -0.230807
# KernelBase.dll.mui                                             -0.179892
# Keylogger traces (messagehooks)                                -0.007989
# Mutants_accessed                                                0.045625
# PresentationFramework.Aero.ni.dll                              -0.025524
# SearchFilterHo                                                 -0.218802
# StaticCache.dat                                                 0.015854
# Susp DLLs (atoms)                                               0.048355
# Susp DLLs/EXEs (dlllist)                                        0.156322
# Unusual process PID                                                  NaN
# Unusual timers.                                                 0.108800
# Y                                                              -0.166143
# comdlg32.dll                                                   -0.185904
# count_run_temp_dir                                              0.091280
# dll_for_proc                                                   -0.045630
# explorer.exe                                                   -0.154715
# feclient.dll                                                   -0.028256
# hidden/Susp DLLs/EXEs(ldermodules)                             -0.057149
# interesting files accessed                                      0.026163
# new services                                                    0.092912
# no. of malfinds                                                 0.091720
# no._of_child                                                   -0.000569
# no._of_envars                                                   0.030284
# no_proc_in_hollow                                               0.127890
# possible_code_injection                                         0.113197
# python.exe                                                      0.053412
# suspicious_files                                                0.028664
# tcl8.5                                                         -0.154868
#
#                                                  ...     \
#                                                  ...
# \nCollects information about system              ...
# \nHas access to autorun registry keys            ...
# \nIdentifies installed programs                  ...
# \nQueries / modifies network settings            ...
# \nQueries / modifies proxy settings              ...
# \nReads information about supported languages    ...
# !IETld!Mutex                                     ...
# Associated service                               ...
# Can access the clipboard                         ...
# Can bypass UAC                                   ...
# Can create atoms                                 ...
# Can create or write to files                     ...
# Can enumerate free disk space                    ...
# Can enumerate username                           ...
# Can restart or shutdown the system               ...
# Can track keyboard strokes                       ...
# IPcount netscan                                  ...
# KernelBase.dll                                   ...
# KernelBase.dll.mui                               ...
# Keylogger traces (messagehooks)                  ...
# Mutants_accessed                                 ...
# PresentationFramework.Aero.ni.dll                ...
# SearchFilterHo                                   ...
# StaticCache.dat                                  ...
# Susp DLLs (atoms)                                ...
# Susp DLLs/EXEs (dlllist)                         ...
# Unusual process PID                              ...
# Unusual timers.                                  ...
# Y                                                ...
# comdlg32.dll                                     ...
# count_run_temp_dir                               ...
# dll_for_proc                                     ...
# explorer.exe                                     ...
# feclient.dll                                     ...
# hidden/Susp DLLs/EXEs(ldermodules)               ...
# interesting files accessed                       ...
# new services                                     ...
# no. of malfinds                                  ...
# no._of_child                                     ...
# no._of_envars                                    ...
# no_proc_in_hollow                                ...
# possible_code_injection                          ...
# python.exe                                       ...
# suspicious_files                                 ...
# tcl8.5                                           ...
#
#                                                interesting files accessed  \
#                                                                  0.040897
# \nCollects information about system                              0.303164
# \nHas access to autorun registry keys                            0.162814
# \nIdentifies installed programs                                  0.000499
# \nQueries / modifies network settings                            0.035856
# \nQueries / modifies proxy settings                              0.711312
# \nReads information about supported languages                    0.419662
# !IETld!Mutex                                                    -0.105952
# Associated service                                               0.021413
# Can access the clipboard                                         0.026163
# Can bypass UAC                                                   0.201937
# Can create atoms                                                 0.004211
# Can create or write to files                                    -0.030118
# Can enumerate free disk space                                    0.029231
# Can enumerate username                                           0.243078
# Can restart or shutdown the system                               0.032060
# Can track keyboard strokes                                       0.003950
# IPcount netscan                                                  0.458859
# KernelBase.dll                                                   0.059722
# KernelBase.dll.mui                                               0.144796
# Keylogger traces (messagehooks)                                  0.028412
# Mutants_accessed                                                 0.695108
# PresentationFramework.Aero.ni.dll                                0.729253
# SearchFilterHo                                                  -0.021955
# StaticCache.dat                                                 -0.161523
# Susp DLLs (atoms)                                                0.315565
# Susp DLLs/EXEs (dlllist)                                         0.204748
# Unusual process PID                                                   NaN
# Unusual timers.                                                  0.315263
# Y                                                               -0.201396
# comdlg32.dll                                                    -0.193550
# count_run_temp_dir                                               0.468415
# dll_for_proc                                                     0.687092
# explorer.exe                                                    -0.190691
# feclient.dll                                                     0.669730
# hidden/Susp DLLs/EXEs(ldermodules)                               0.544625
# interesting files accessed                                       1.000000
# new services                                                     0.199477
# no. of malfinds                                                  0.416324
# no._of_child                                                     0.082131
# no._of_envars                                                    0.316573
# no_proc_in_hollow                                                0.214667
# possible_code_injection                                          0.121745
# python.exe                                                       0.145205
# suspicious_files                                                 0.346399
# tcl8.5                                                           0.088080
#
#                                                new services  no. of malfinds  \
#                                                   -0.135560         0.004753
# \nCollects information about system               -0.073386         0.058094
# \nHas access to autorun registry keys              0.098053         0.320809
# \nIdentifies installed programs                    0.336363         0.058874
# \nQueries / modifies network settings             -0.020883         0.373935
# \nQueries / modifies proxy settings                0.199745         0.489149
# \nReads information about supported languages      0.288518         0.561631
# !IETld!Mutex                                      -0.208060        -0.200469
# Associated service                                 0.009683        -0.023455
# Can access the clipboard                           0.092912         0.091720
# Can bypass UAC                                     0.121005         0.227162
# Can create atoms                                   0.125167         0.155402
# Can create or write to files                      -0.090944        -0.082288
# Can enumerate free disk space                      0.112347         0.162568
# Can enumerate username                             0.156949         0.276984
# Can restart or shutdown the system                 0.079768         0.169626
# Can track keyboard strokes                         0.141721         0.160777
# IPcount netscan                                    0.227395         0.531334
# KernelBase.dll                                    -0.131353         0.057044
# KernelBase.dll.mui                                -0.096776         0.022546
# Keylogger traces (messagehooks)                    0.006489         0.069638
# Mutants_accessed                                   0.235680         0.411394
# PresentationFramework.Aero.ni.dll                  0.175819         0.298842
# SearchFilterHo                                    -0.203987         0.101910
# StaticCache.dat                                   -0.106450         0.049740
# Susp DLLs (atoms)                                  0.239439         0.360350
# Susp DLLs/EXEs (dlllist)                           0.149664         0.334324
# Unusual process PID                                     NaN              NaN
# Unusual timers.                                    0.290189         0.548066
# Y                                                 -0.238640        -0.280584
# comdlg32.dll                                      -0.188706        -0.150141
# count_run_temp_dir                                 0.059875         0.449728
# dll_for_proc                                       0.260422         0.504849
# explorer.exe                                      -0.116994        -0.042068
# feclient.dll                                       0.173508         0.330199
# hidden/Susp DLLs/EXEs(ldermodules)                 0.301849         0.501059
# interesting files accessed                         0.199477         0.416324
# new services                                       1.000000         0.387070
# no. of malfinds                                    0.387070         1.000000
# no._of_child                                       0.095055         0.313456
# no._of_envars                                      0.145391         0.593161
# no_proc_in_hollow                                  0.430284         0.505014
# possible_code_injection                            0.041555         0.436374
# python.exe                                         0.057042         0.490585
# suspicious_files                                   0.183423         0.432963
# tcl8.5                                            -0.145791         0.237015
#
#                                                no._of_child  no._of_envars  \
#                                                   -0.124369      -0.214008
# \nCollects information about system               -0.091247      -0.254727
# \nHas access to autorun registry keys              0.170273       0.255301
# \nIdentifies installed programs                    0.020290       0.058810
# \nQueries / modifies network settings              0.203171       0.300346
# ...
# PresentationFramework.Aero.ni.dll                  0.038635       0.286168
# SearchFilterHo                                    -0.007959       0.070412
# StaticCache.dat                                   -0.074241      -0.108185
# Susp DLLs (atoms)                                  0.113705       0.386503
# Susp DLLs/EXEs (dlllist)                          -0.006000      -0.150034
# Unusual process PID                                     NaN            NaN
# Unusual timers.                                    0.210052       0.727222
# Y                                                 -0.177391      -0.526760
# comdlg32.dll                                      -0.114215      -0.336988
# count_run_temp_dir                                 0.080967       0.227889
# dll_for_proc                                       0.154609       0.598180
# explorer.exe                                      -0.061092      -0.430554
# feclient.dll                                       0.111932       0.316810
# hidden/Susp DLLs/EXEs(ldermodules)                 0.190529       0.548182
# interesting files accessed                         0.082131       0.316573
# new services                                       0.095055       0.145391
# no. of malfinds                                    0.313456       0.593161
# no._of_child                                       1.000000       0.222564
# no._of_envars                                      0.222564       1.000000
# no_proc_in_hollow                                  0.228722       0.545543
# possible_code_injection                            0.142619       0.342220
# python.exe                                         0.048123       0.186254
# suspicious_files                                   0.184656       0.482214
# tcl8.5                                             0.003111       0.268921
#
#                                                no_proc_in_hollow  \
#                                                        -0.548829
# \nCollects information about system                    -0.606914
# \nHas access to autorun registry keys                   0.238745
# \nIdentifies installed programs                         0.062768
# \nQueries / modifies network settings                   0.134048
# \nQueries / modifies proxy settings                     0.290887
# \nReads information about supported languages           0.587406
# !IETld!Mutex                                           -0.765069
# Associated service                                      0.026845
# Can access the clipboard                                0.127890
# Can bypass UAC                                          0.272932
# Can create atoms                                        0.244133
# Can create or write to files                           -0.546030
# Can enumerate free disk space                           0.223007
# Can enumerate username                                  0.263605
# Can restart or shutdown the system                      0.217786
# Can track keyboard strokes                              0.249259
# IPcount netscan                                         0.654943
# KernelBase.dll                                         -0.493266
# KernelBase.dll.mui                                     -0.566054
# Keylogger traces (messagehooks)                         0.053795
# Mutants_accessed                                        0.191930
# PresentationFramework.Aero.ni.dll                       0.152410
# SearchFilterHo                                         -0.270057
# StaticCache.dat                                        -0.456284
# Susp DLLs (atoms)                                       0.328049
# Susp DLLs/EXEs (dlllist)                               -0.288797
# Unusual process PID                                          NaN
# Unusual timers.                                         0.775932
# Y                                                      -0.807206
# comdlg32.dll                                           -0.660152
# count_run_temp_dir                                     -0.061467
# dll_for_proc                                            0.378388
# explorer.exe                                           -0.605147
# feclient.dll                                            0.182377
# hidden/Susp DLLs/EXEs(ldermodules)                      0.485353
# interesting files accessed                              0.214667
# new services                                            0.430284
# no. of malfinds                                         0.505014
# no._of_child                                            0.228722
# no._of_envars                                           0.545543
# no_proc_in_hollow                                       1.000000
# possible_code_injection                                 0.143737
# python.exe                                             -0.261415
# suspicious_files                                        0.429417
# tcl8.5                                                 -0.396021
#
#                                                possible_code_injection  \
#                                                              -0.013219
# \nCollects information about system                           0.072202
# \nHas access to autorun registry keys                         0.134259
# \nIdentifies installed programs                               0.038095
# \nQueries / modifies network settings                         0.558043
# \nQueries / modifies proxy settings                           0.258112
# \nReads information about supported languages                 0.137838
# !IETld!Mutex                                                 -0.079476
# Associated service                                           -0.014238
# Can access the clipboard                                      0.113197
# Can bypass UAC                                                0.077759
# Can create atoms                                              0.018051
# Can create or write to files                                 -0.016105
# Can enumerate free disk space                                 0.081297
# Can enumerate username                                        0.119561
# Can restart or shutdown the system                            0.128958
# Can track keyboard strokes                                    0.044142
# IPcount netscan                                               0.187391
# KernelBase.dll                                               -0.075910
# KernelBase.dll.mui                                           -0.067970
# Keylogger traces (messagehooks)                               0.125622
# Mutants_accessed                                              0.100995
# PresentationFramework.Aero.ni.dll                             0.035796
# SearchFilterHo                                                0.019071
# StaticCache.dat                                              -0.012008
# Susp DLLs (atoms)                                             0.119101
# Susp DLLs/EXEs (dlllist)                                      0.129489
# Unusual process PID                                                NaN
# Unusual timers.                                               0.237942
# Y                                                            -0.108580
# comdlg32.dll                                                 -0.090402
# count_run_temp_dir                                            0.108902
# dll_for_proc                                                  0.067796
# explorer.exe                                                 -0.093396
# feclient.dll                                                  0.030193
# hidden/Susp DLLs/EXEs(ldermodules)                            0.074061
# interesting files accessed                                    0.121745
# new services                                                  0.041555
# no. of malfinds                                               0.436374
# no._of_child                                                  0.142619
# no._of_envars                                                 0.342220
# no_proc_in_hollow                                             0.143737
# possible_code_injection                                       1.000000
# python.exe                                                    0.231176
# suspicious_files                                              0.139989
# tcl8.5                                                        0.155106
#
#                                                python.exe  suspicious_files  \
#                                                  0.557311         -0.197736
# \nCollects information about system              0.517892         -0.167832
# \nHas access to autorun registry keys            0.148847          0.175695
# \nIdentifies installed programs                  0.012907          0.035921
# \nQueries / modifies network settings            0.038827          0.122997
# \nQueries / modifies proxy settings              0.112731          0.336520
# \nReads information about supported languages    0.182418          0.433912
# !IETld!Mutex                                     0.428980         -0.361289
# Associated service                              -0.061272          0.013337
# Can access the clipboard                         0.053412          0.028664
# Can bypass UAC                                   0.026438          0.098220
# Can create atoms                                 0.057883          0.045757
# Can create or write to files                     0.451030         -0.296416
# Can enumerate free disk space                    0.068644          0.044724
# Can enumerate username                           0.057488          0.093087
# Can restart or shutdown the system               0.053838          0.050059
# Can track keyboard strokes                       0.060540          0.038066
# IPcount netscan                                 -0.078306          0.565401
# KernelBase.dll                                   0.564019         -0.095857
# KernelBase.dll.mui                               0.493256         -0.175641
# Keylogger traces (messagehooks)                 -0.013056          0.042030
# Mutants_accessed                                 0.168731          0.267020
# PresentationFramework.Aero.ni.dll                0.062804          0.282383
# SearchFilterHo                                   0.233335          0.031134
# StaticCache.dat                                  0.573411         -0.186087
# Susp DLLs (atoms)                                0.074589          0.311462
# Susp DLLs/EXEs (dlllist)                         0.670949         -0.044651
# Unusual process PID                                   NaN               NaN
# Unusual timers.                                 -0.085177          0.563340
# Y                                                0.408817         -0.404318
# comdlg32.dll                                     0.455599         -0.306191
# count_run_temp_dir                               0.605507          0.127928
# dll_for_proc                                     0.164462          0.445158
# explorer.exe                                     0.467130         -0.295229
# feclient.dll                                     0.069529          0.305912
# hidden/Susp DLLs/EXEs(ldermodules)              -0.001352          0.419700
# interesting files accessed                       0.145205          0.346399
# new services                                     0.057042          0.183423
# no. of malfinds                                  0.490585          0.432963
# no._of_child                                     0.048123          0.184656
# no._of_envars                                    0.186254          0.482214
# no_proc_in_hollow                               -0.261415          0.429417
# possible_code_injection                          0.231176          0.139989
# python.exe                                       1.000000          0.019303
# suspicious_files                                 0.019303          1.000000
# tcl8.5                                           0.648229          0.014488
#
#                                                  tcl8.5
#                                                0.647959
# \nCollects information about system            0.665468
# \nHas access to autorun registry keys          0.018157
# \nIdentifies installed programs                0.019847
# \nQueries / modifies network settings          0.020355
# \nQueries / modifies proxy settings            0.000131
# \nReads information about supported languages  0.033614
# !IETld!Mutex                                   0.619285
# Associated service                            -0.039846
# Can access the clipboard                      -0.154868
# Can bypass UAC                                -0.173375
# Can create atoms                              -0.110960
# Can create or write to files                   0.406201
# Can enumerate free disk space                 -0.170194
# Can enumerate username                        -0.177614
# Can restart or shutdown the system            -0.148214
# Can track keyboard strokes                    -0.129598
# IPcount netscan                               -0.027986
# KernelBase.dll                                 0.871838
# KernelBase.dll.mui                             0.671376
# Keylogger traces (messagehooks)               -0.004296
# Mutants_accessed                               0.075365
# PresentationFramework.Aero.ni.dll              0.096576
# SearchFilterHo                                 0.654094
# StaticCache.dat                                0.708822
# Susp DLLs (atoms)                              0.002278
# Susp DLLs/EXEs (dlllist)                       0.453883
# Unusual process PID                                 NaN
# Unusual timers.                               -0.132604
# Y                                              0.628657
# comdlg32.dll                                   0.703427
# count_run_temp_dir                             0.564258
# dll_for_proc                                   0.224762
# explorer.exe                                   0.577043
# feclient.dll                                   0.106917
# hidden/Susp DLLs/EXEs(ldermodules)             0.051637
# interesting files accessed                     0.088080
# new services                                  -0.145791
# no. of malfinds                                0.237015
# no._of_child                                   0.003111
# no._of_envars                                  0.268921
# no_proc_in_hollow                             -0.396021
# possible_code_injection                        0.155106
# python.exe                                     0.648229
# suspicious_files                               0.014488
# tcl8.5                                         1.000000
#
# [46 rows x 46 columns]
# Y
# set(['Y'])
#
#
# Collects information about system
#
# Has access to autorun registry keys
#
# Identifies installed programs
#
# Queries / modifies network settings
#
# Queries / modifies proxy settings
#
# Reads information about supported languages
# !IETld!Mutex
# Associated service
# Can access the clipboard
# Can bypass UAC
# Can create atoms
# Can create or write to files
# Can enumerate free disk space
# Can enumerate username
# Can restart or shutdown the system
# Can track keyboard strokes
# IPcount netscan
# KernelBase.dll
# KernelBase.dll.mui
# Keylogger traces (messagehooks)
# Mutants_accessed
# PresentationFramework.Aero.ni.dll
# SearchFilterHo
# StaticCache.dat
# Susp DLLs (atoms)
# Susp DLLs/EXEs (dlllist)
# Unusual process PID
# Unusual timers.
# Y
# comdlg32.dll
# count_run_temp_dir
# dll_for_proc
# explorer.exe
# feclient.dll
# hidden/Susp DLLs/EXEs(ldermodules)
# interesting files accessed
# new services
# no. of malfinds
# no._of_child
# no._of_envars
# no_proc_in_hollow
# possible_code_injection
# python.exe
# suspicious_files
# tcl8.5

# %%
mylist=mylist.drop('BootstrapperApplicationData.xml',axis=1)
mylist=mylist.drop('Devdiv',axis=1)
mylist=mylist.drop('System.Data.dll',axis=1)
mylist=mylist.drop('',axis=1)
mylist=mylist.drop('Associated service ',axis=1)
mylist=mylist.drop('Susp DLLs/EXEs (dlllist)',axis=1)

mylist=mylist.drop('\nCollects information about system',axis=1)
mylist=mylist.drop('Unusual timers.',axis=1)
mylist=mylist.drop('SearchFilterHo',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1dce8bf42fd9> in <module>()
#       1
# ----> 2 mylist=mylist.drop('BootstrapperApplicationData.xml',axis=1)
#       3 mylist=mylist.drop('Devdiv',axis=1)
#       4 mylist=mylist.drop('System.Data.dll',axis=1)
#       5 mylist=mylist.drop('',axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['BootstrapperApplicationData.xml'] not contained in axis

# %%
mylist=mylist.drop('clbcatq.dll',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-852e1901c5a7> in <module>()
# ----> 1 mylist=mylist.drop('clbcatq.dll',axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['clbcatq.dll'] not contained in axis

# %%
for k in range(1,2):
    

            train, test = train_test_split(mylist, test_size = 0.3)
            #print X_train
            X_train=pd.DataFrame(train)
            

            Y_train=list(X_train['Y'])
            #print Y_train
            
            

            X_train=X_train.drop('Y',axis=1)


            X_test=pd.DataFrame(test)
            

            Y_test=list(X_test['Y'])
            X_test=X_test.drop('Y',axis=1)

            #for name in X_train :
            #      print name
            #print len(X_test)   
            clf = DecisionTreeClassifier(random_state=0)
            #clf=svm.SVC()
            clf = clf.fit(X_train,Y_train)
            #print clf.feature_importances_

            Y_pred = clf.predict(X_test)
           # print("accuracy on the training subset: ",clf.score(X_train,Y_train))
            #print("accuracy on the testing subset: ",clf.score(X_test,Y_test))
            #print Y_test[:200]
            #print Y_pred[:200]            
            for i in range(0,len(Y_pred)):
                if Y_pred[i]==Y_test[i]:
                    continue
                else :
                    print 'F'+str(Y_test[i])+' '+str(Y_pred[i])
            print clf.score(X_test,Y_test)
            coun=0
            '''for name in mylist:
                    print name+'   '+str(coun)
                    coun=coun+1'''
# Out:
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# F0 1
# 0.9506545820745217

# %%
# Out:
# 0.47633434038267874

# %%
toshow=[]
for na in X_train:
    featurevals={'name':na,
                 'mean M':df0[na].mean(),
                 'Sd M':df0[na].std(),
                 'mean B':df1[na].mean(),
                 'Sd B'  :df1[na].std() 
                    
                }
    #print na+' '+str(df0[na].mean())+' '+str(df0[na].std())+' '+str(df1[na].mean())+' '+str(df1[na].std())
    toshow.append(featurevals)
print toshow
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-41806cd2191e> in <module>()
#       3 for na in X_train:
#       4     featurevals={'name':na,
# ----> 5                  'mean M':df0[na].mean(),
#       6                  'Sd M':df0[na].std(),
#       7                  'mean B':df1[na].mean(),
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PresentationFramework.Aero.ni.dll'

# %%
showdf=pd.DataFrame().from_records(toshow).fillna(0).round(3)
print showdf
showdf.to_csv('/home/anmol/Downloads/file_name.csv')
# Out:
#       Sd B    Sd M  mean B  mean M  \
# 0    0.464   0.468   0.314   0.323
# 1   10.550  10.789   6.165   7.401
# 2    6.804   9.434   2.872   5.253
# 3    0.092   0.270   0.005   0.008
# 4    0.430   0.228   0.095   0.027
# 5    1.887   1.967   0.858   1.036
# 6    0.993   0.949   0.876   0.683
# 7    0.220   0.359   0.051   0.152
# 8    0.925   0.000   0.032   0.000
# 9    0.219   0.223   0.051   0.053
# 10   0.635   0.426   0.167   0.087
# 11   0.225   0.172   0.051   0.031
# 12   1.070   0.923   0.466   0.356
# 13   0.316   0.305   0.090   0.079
# 14   0.270   0.237   0.065   0.053
# 15   0.220   0.191   0.051   0.038
# 16   0.386   0.341   0.091   0.065
# 17   1.728   1.655   3.999   3.988
# 18   0.471   0.483   0.332   0.370
# 19   0.397   0.351   0.196   0.144
# 20   5.507   6.259   0.415   0.758
# 21   4.542   5.182   2.017   2.870
#
#                                              name
# 0
# 1             \nCollects information about system
# 2           \nHas access to autorun registry keys
# 3                 \nIdentifies installed programs
# 4           \nQueries / modifies network settings
# 5             \nQueries / modifies proxy settings
# 6   \nReads information about supported languages
# 7                                    !IETld!Mutex
# 8                             Associated service
# 9                       Can access the clipboard
# 10                                Can bypass UAC
# 11                              Can create atoms
# 12                  Can create or write to files
# 13                 Can enumerate free disk space
# 14                        Can enumerate username
# 15            Can restart or shutdown the system
# 16                    Can track keyboard strokes
# 17                                IPcount netscan
# 18                                 KernelBase.dll
# 19                             KernelBase.dll.mui
# 20                Keylogger traces (messagehooks)
# 21                               Mutants_accessed
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-42-cd11cc903e9d> in <module>()
#       1 showdf=pd.DataFrame().from_records(toshow).fillna(0).round(3)
#       2 print showdf
# ----> 3 showdf.to_csv('/home/anmol/Downloads/file_name.csv')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/formats/format.pyc in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/common.pyc in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     385         if compat.PY2:
#     386             # Python 2
# --> 387             f = open(path_or_buf, mode)
#     388         elif encoding:
#     389             # Python 3 and encoding
#
# IOError: [Errno 2] No such file or directory: '/home/anmol/Downloads/file_name.csv'

# %%
clf = DecisionTreeClassifier(random_state=0)

clf = clf.fit(X_train,Y_train)
print clf.feature_importances_

Y_pred = clf.predict(X_test)
print("accuracy on the training subset: ",clf.score(X_train,Y_train))
print("accuracy on the testing subset: ",clf.score(X_test,Y_test))
# Out:
# [1.75203767e-03 9.73479747e-03 7.07929196e-03 0.00000000e+00
#  0.00000000e+00 6.58338496e-02 3.40182531e-03 7.00218656e-01
#  0.00000000e+00 0.00000000e+00 9.03286584e-04 0.00000000e+00
#  1.84586160e-03 2.55413289e-03 3.22666357e-04 1.43384970e-03
#  7.25999304e-04 2.20133339e-02 0.00000000e+00 1.91472344e-03
#  0.00000000e+00 7.63975044e-03 0.00000000e+00 4.17035042e-03
#  1.20999884e-03 7.12784614e-03 1.82501541e-02 0.00000000e+00
#  2.08017974e-03 4.76941446e-04 1.84697497e-03 1.47304050e-02
#  1.20999884e-03 0.00000000e+00 3.66448941e-02 9.72461720e-03
#  4.88373026e-03 6.25959958e-03 7.05504253e-03 0.00000000e+00
#  3.82092929e-03 5.92222209e-03 4.03332947e-04 4.68087199e-02
#  0.00000000e+00]
# ('accuracy on the training subset: ', 0.9141130772550712)
# ('accuracy on the testing subset: ', 0.9506545820745217)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from pandas_ml import ConfusionMatrix
cm = ConfusionMatrix(Y_test, Y_pred) 
print cm                    
fig, ax = plot_confusion_matrix(conf_mat=cm)
plt.figure(figsize=(1,1))


plt.show()
# Out:
# Predicted  False  True  __all__
# Actual
# False        415    49      464
# True           0   529      529
# __all__      415   578      993
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-a113bba16ac9> in <module>()
#       5 cm = ConfusionMatrix(Y_test, Y_pred)
#       6 print cm
# ----> 7 fig, ax = plot_confusion_matrix(conf_mat=cm)
#       8 plt.figure(figsize=(1,1))
#       9
#
# /usr/local/lib/python2.7/dist-packages/mlxtend/plotting/plot_confusion_matrix.pyc in plot_confusion_matrix(conf_mat, hide_spines, hide_ticks, figsize, cmap, alpha)
#      42     if cmap is None:
#      43         cmap = plt.cm.Blues
# ---> 44     ax.matshow(conf_mat, cmap=cmap, alpha=alpha)
#      45     for i in range(conf_mat.shape[0]):
#      46         for j in range(conf_mat.shape[1]):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in matshow(self, Z, **kwargs)
#    7720         """
#    7721         Z = np.asanyarray(Z)
# -> 7722         nr, nc = Z.shape
#    7723         kw = {'origin': 'upper',
#    7724               'interpolation': 'nearest',
#
# ValueError: need more than 0 values to unpack

# %%
clf = svm.SVC()
clf.fit(X_train, Y_train)  
print("accuracy on the testing subset: ",clf.score(X_test,Y_test))
# Out:
# ('accuracy on the testing subset: ', 0.9969788519637462)

# %%
from sklearn.preprocessing import StandardScaler  
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.metrics import classification_report, confusion_matrix  
scaler = StandardScaler()  
scaler.fit(X_train)

X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)  
classifier = KNeighborsClassifier(n_neighbors=5)  
classifier.fit(X_train, Y_train)  
y_pred = classifier.predict(X_test)  

print(confusion_matrix(Y_test, y_pred))  
print(classification_report(Y_test, y_pred))  
print classifier.score(X_test,Y_test)
cm = confusion_matrix(Y_test, 
                      y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm)
plt.figure(figsize=(1,1))


plt.show()
# Out:
# [[456   8]
#  [  0 529]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.98      0.99       464
#           1       0.99      1.00      0.99       529
#
# avg / total       0.99      0.99      0.99       993
#
# 0.9919436052366566

# %%
# fit model no training data
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
model = XGBClassifier()

model.fit(X_train, Y_train)
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(Y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
#print(confusion_matrix(Y_test, y_pred))  
#print(classification_report(Y_test, y_pred))  
#print classifier.score(X_test,Y_test)
cm = confusion_matrix(Y_test, 
                      y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm)
plt.figure(figsize=(1,1))


plt.show()
# Out:
# Accuracy: 100.00%
# /usr/local/lib/python2.7/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
import numpy as np
import pandas as pd
d = {'\n one' : df0['no. of malfinds']*0.23107976+df0['no._of_child']*0.75725494+df0['no._of_envars']*0.0116653,
             'two' : df1['no. of malfinds']*0.23107976+df1['no._of_child']*0.75725494+df1['no._of_envars']*0.0116653}

#print df0['no. of malfinds']
#print 'HEllo'
print df0['no._of_child']
#print 
#print df0['no._of_envars']
df = pd.DataFrame(d)
df.plot(style=['o','rx'],figsize=(20,10))
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
# 5       0
# 6       0
# 7       1
# 8       0
# 9       1
# 10      0
# 11      0
# 12      6
# 13      1
# 14      1
# 15      2
# 16      1
# 17      0
# 18      1
# 19      1
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      0
# 26      1
# 27      0
# 28      0
# 29      0
#        ..
# 1736    0
# 1737    0
# 1738    1
# 1739    1
# 1740    0
# 1741    1
# 1742    1
# 1743    1
# 1744    1
# 1745    1
# 1746    1
# 1747    0
# 1748    1
# 1749    1
# 1750    0
# 1751    0
# 1752    0
# 1753    0
# 1754    0
# 1755    1
# 1756    1
# 1757    0
# 1758    0
# 1759    0
# 1760    1
# 1761    0
# 1762    0
# 1763    0
# 1764    1
# 1765    0
# Name: no._of_child, Length: 1766, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
import pandas as pd
from scipy.interpolate import griddata
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import pandas as pd
from sys import argv
# create 1D-arrays from the 2D-arrays
#x = X.reshape(1600)
#y = Y.reshape(1600)
#z = Z.reshape(1600)
#xyz = {'x': x, 'y': y, 'z': z}
xyz = {'x' : df0['no._of_envars'] ,
         'y': df0['no._of_child'] ,
         'z': df0['no. of malfinds'] }
xyz1 = {'x' : df1['no._of_envars'] ,
         'y': df1['no._of_child'] ,
         'z': df1['no. of malfinds'] }


# put the data into a pandas DataFrame (this is what my data looks like)
df = pd.DataFrame(xyz, index=range(len(xyz['x']))) 
df_1 = pd.DataFrame(xyz1, index=range(len(xyz['x']))) 



fig = plt.figure(figsize=(20,10))
ax = Axes3D(fig)
surf = ax.plot_trisurf(df.x, df.y, df.z, cmap=cm.jet, linewidth=0.1)
surf1 = ax.plot_trisurf(df_1.x, df_1.y, df_1.z, cmap=cm.jet, linewidth=0.1)
#fig.colorbar(surf, shrink=0.5, aspect=5)
plt.savefig('teste.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-a49ee9a0a06e> in <module>()
#      35 ax = Axes3D(fig)
#      36 surf = ax.plot_trisurf(df.x, df.y, df.z, cmap=cm.jet, linewidth=0.1)
# ---> 37 surf1 = ax.plot_trisurf(df_1.x, df_1.y, df_1.z, cmap=cm.jet, linewidth=0.1)
#      38 #fig.colorbar(surf, shrink=0.5, aspect=5)
#      39 plt.savefig('teste.pdf')
#
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/mplot3d/axes3d.pyc in plot_trisurf(self, *args, **kwargs)
#    1990         lightsource = kwargs.pop('lightsource', None)
#    1991
# -> 1992         tri, args, kwargs = Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#    1993         if 'Z' in kwargs:
#    1994             z = np.asarray(kwargs.pop('Z'))
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/tri/triangulation.pyc in get_from_args_and_kwargs(*args, **kwargs)
#     162             mask = kwargs.pop('mask', None)
#     163
# --> 164             triangulation = Triangulation(x, y, triangles, mask)
#     165         return triangulation, args, kwargs
#     166
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/tri/triangulation.pyc in __init__(self, x, y, triangles, mask)
#      53             # No triangulation specified, so use matplotlib._qhull to obtain
#      54             # Delaunay triangulation.
# ---> 55             self.triangles, self._neighbors = _qhull.delaunay(x, y)
#      56             self.is_delaunay = True
#      57         else:
#
# RuntimeError: Error in qhull Delaunay triangulation calculation: input inconsistency (exitcode=1); use python verbose option (-v) to see original qhull error.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as plt
plt.plot(df0['no._of_child'],df0['no._of_envars'], 'bx')
plt.plot(df1['no._of_child'],df1['no._of_envars'], 'ro')
plt.axis([0, 20, 0,30 ])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.pyplot as plt
plt.plot(df0['no._of_envars'],df0['no._of_child'], 'ro')
plt.plot(df1['no._of_envars'],df1['no._of_child'], 'bx')
plt.axis([0, 10, 0, 70])

plt.show()

# %%
import numpy as np
import pandas as pd
for name in X_train:
    print name
    if name in df0 and name in df1:
        d = {name+'\n one' : df0[name],
             'two' : df1[name]}

        df = pd.DataFrame(d)
        print name +'#################################'
        if name== 'no. of malfinds':
              d = {name+'\n one' : df0[name]*0.23107976,
                  'two' : df1[name]*0.23107976}
        elif name== 'no._of_child':
              d = {name+'\n one' : df0[name]*0.75725494,
                  'two' : df1[name]*0.75725494} 
        elif name== 'no._of_envars':
              d = {name+'\n one' : df0[name]*0.0116653,
                  'two' : df1[name]*0.0116653}
        else :
              d = {name+'\n one' : df0[name],
             'two' : df1[name]}

        df = pd.DataFrame(d)
        df = pd.DataFrame(d)   
        df.plot(style=['o','rx'],figsize=(20,10))
        continue
# Out:
# #################################
#
# Collects information about system
#
# Collects information about system#################################
#
# Has access to autorun registry keys
#
# Has access to autorun registry keys#################################
#
# Identifies installed programs
#
# Identifies installed programs#################################
#
# Queries / modifies network settings
#
# Queries / modifies network settings#################################
#
# Reads information about supported languages
#
# Reads information about supported languages#################################
# Associated service
# Associated service #################################
# IPcount netscan
# IPcount netscan#################################
# KernelBase.dll
# KernelBase.dll#################################
# Keylogger traces (messagehooks)
# Keylogger traces (messagehooks)#################################
# SearchFilterHo
# SearchFilterHo#################################
# Susp DLLs (atoms)
# Susp DLLs (atoms)#################################
# Susp DLLs/EXEs (dlllist)
# Susp DLLs/EXEs (dlllist)#################################
# Unusual process PID
# Unusual process PID#################################
# Unusual timers.
# Unusual timers.#################################
# api-ms-win-core-synch-l1-2-0.dll
# new services
# new services#################################
# no._of_child
# no._of_child#################################
# no_proc_in_hollow
# no_proc_in_hollow#################################
# possible_code_injection
# possible_code_injection#################################
# python.exe
# python.exe#################################
# suspicious_files
# suspicious_files#################################
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
